# %%
import pandas as pd

london_prescriptions_2011 = pd.read_csv('prescriptions/2011/2011.csv')
london_prescriptions_2012 = pd.read_csv('prescriptions/2012/2012.csv')
london_prescriptions_2013 = pd.read_csv('prescriptions/2013/2013.csv')

# %%
london_prescriptions_2011
# Out:
#         Unnamed: 0  SHA  PCT PRACTICE         BNF CODE  \
# 0          5520911  Q35  5PV   F81062  0403010B0AAAGAG
# 1          5520912  Q35  5PV   F81062  0403010B0AAAHAH
# 2          5520913  Q35  5PV   F81062  0403010B0AAAIAI
# 3          5520914  Q35  5PV   F81062  0403010J0AAAAAA
# 4          5520915  Q35  5PV   F81062  0403010J0AAAIAI
# ...            ...  ...  ...      ...              ...
# 489536     7918974  Q37  5P5   Y01660  0403040W0AAAJAJ
# 489537     7918975  Q37  5P5   Y01660  0403040W0AAAKAK
# 489538     7918976  Q37  5P5   Y01660  0403040W0AAALAL
# 489539     7918977  Q37  5P5   Y01660  0403040X0AAAPAP
# 489540     7918978  Q37  5P5   Y01660  0403040Y0AAAAAA
#
#        BNF NAME                                      ITEMS    NIC          \
# 0          Amitriptyline HCl_Tab 10mg                     32        34.96
# 1          Amitriptyline HCl_Tab 25mg                     21        21.52
# 2          Amitriptyline HCl_Tab 50mg                      3         3.84
# 3          Dosulepin HCl_Cap 25mg                          5        13.52
# 4          Dosulepin HCl_Tab 75mg                          7        13.64
# ...                                             ...      ...          ...
# 489536     Venlafaxine_Tab 75mg M/R                        1        11.20
# 489537     Venlafaxine_Tab 150mg M/R                       1         2.49
# 489538     Venlafaxine_Tab 225mg M/R                       1        15.68
# 489539     Mirtazapine_Tab 45mg                            1         3.40
# 489540     Duloxetine HCl_Cap G/R 30mg                     1        22.40
#
#         ACT COST     QUANTITY  PERIOD                     Postcode
# 0             33.25      1152  201108                       IG62TA
# 1             20.51       700  201108                       IG62TA
# 2              3.64       112  201108                       IG62TA
# 3             12.63       364  201108                       IG62TA
# 4             12.78       308  201108                       IG62TA
# ...             ...       ...     ...                 ...      ...
# 489536        10.35        30  201109                       KT59AL
# 489537         2.33         4  201109                       KT59AL
# 489538        14.48        14  201109                       KT59AL
# 489539         3.17        28  201109                       KT59AL
# 489540        20.67        28  201109                       KT59AL
#
# [489541 rows x 13 columns]

# %%
full_postalcode_info = pd.read_csv('C:/users/muize/Downloads/london_postcodes-ons-postcodes-directory-feb22.csv')

# %%
postal_code_gss_code = full_postalcode_info[['pcd', 'osward']]

# %%
postal_code_gss_code['pcd'] = postal_code_gss_code['pcd'].str.replace(' ', '')
# Out:
# C:\Users\muize\AppData\Local\Temp\ipykernel_15892\3941782938.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   postal_code_gss_code['pcd'] = postal_code_gss_code['pcd'].str.replace(' ', '')

# %%
london_prescriptions_2011['Postcode'] = london_prescriptions_2011['Postcode'].str.replace(' ', '')
london_prescriptions_2012['Postcode'] = london_prescriptions_2012['Postcode'].str.replace(' ', '')
london_prescriptions_2013['Postcode'] = london_prescriptions_2013['Postcode'].str.replace(' ', '')

# %%
london_prescriptions_2011['Postcode']
# Out:
# 0         IG62TA
# 1         IG62TA
# 2         IG62TA
# 3         IG62TA
# 4         IG62TA
#            ...
# 489536    KT59AL
# 489537    KT59AL
# 489538    KT59AL
# 489539    KT59AL
# 489540    KT59AL
# Name: Postcode, Length: 489541, dtype: object

# %%
london_prescriptions_2011_ward = london_prescriptions_2011.merge(postal_code_gss_code, left_on='Postcode', right_on='pcd', how='left')
london_prescriptions_2012_ward = london_prescriptions_2012.merge(postal_code_gss_code, left_on='Postcode', right_on='pcd', how='left')
london_prescriptions_2013_ward = london_prescriptions_2013.merge(postal_code_gss_code, left_on='Postcode', right_on='pcd', how='left')

# %%
london_prescriptions_2011_ward[london_prescriptions_2011_ward['osward'].isna()]['Postcode']
# Out:
# Series([], Name: Postcode, dtype: object)

# %%
london_prescriptions_2011_ward_edited = london_prescriptions_2011_ward[london_prescriptions_2011_ward['osward'].notna()]
london_prescriptions_2012_ward_edited = london_prescriptions_2012_ward[london_prescriptions_2012_ward['osward'].notna()]
london_prescriptions_2013_ward_edited = london_prescriptions_2013_ward[london_prescriptions_2013_ward['osward'].notna()]

# %%
ward_statistics = pd.read_csv('C:/users/muize/Downloads/ward-atlas-data.csv', encoding= 'unicode_escape', header=[0,1])

# %%
list(ward_statistics.columns)
# Out:
# [('Unnamed: 0_level_0', 'Codes'),
#  ('Unnamed: 1_level_0', 'New Code'),
#  ('Unnamed: 2_level_0', 'Borough'),
#  ('Unnamed: 3_level_0', 'Names'),
#  ('Population and Age; Population Estimates and Projections; 2001', '2001'),
#  ('Population and Age; Population Estimates and Projections; 2006', '2006'),
#  ('Population and Age; Population Estimates and Projections; 2011', '2011'),
#  ('Population and Age; Population Estimates and Projections; 2013', '2013'),
#  ('Population and Age; Population Estimates and Projections; 2014', '2014'),
#  ('Population and Age; Population Estimates and Projections; 2015', '2015'),
#  ('Population and Age; Population Estimates and Projections; 2016', '2016'),
#  ('Population and Age; Population Estimates and Projections; 2018', '2018'),
#  ('Population and Age; Population Estimates and Projections; 2023', '2023'),
#  ('Population and Age; Population Estimates and Projections; 2028', '2028'),
#  ('Population and Age; Age structure (percentage) - 2013; Aged 0-15',
#   'Aged 0-15'),
#  ('Population and Age; Age structure (percentage) - 2013; Aged 16-64',
#   'Aged 16-64'),
#  ('Population and Age; Age structure (percentage) - 2013; Aged 65+',
#   'Aged 65+'),
#  ('Population and Age; Aged 0-15; 2002', '2002'),
#  ('Population and Age; Aged 0-15; 2004', '2004'),
#  ('Population and Age; Aged 0-15; 2006', '2006'),
#  ('Population and Age; Aged 0-15; 2008', '2008'),
#  ('Population and Age; Aged 0-15; 2010', '2010'),
#  ('Population and Age; Aged 0-15; 2011', '2011'),
#  ('Population and Age; Aged 0-15; 2012', '2012'),
#  ('Population and Age; Aged 0-15; 2013', '2013'),
#  ('Population and Age; Aged 16-64; 2002', '2002'),
#  ('Population and Age; Aged 16-64; 2004', '2004'),
#  ('Population and Age; Aged 16-64; 2006', '2006'),
#  ('Population and Age; Aged 16-64; 2008', '2008'),
#  ('Population and Age; Aged 16-64; 2010', '2010'),
#  ('Population and Age; Aged 16-64; 2011', '2011'),
#  ('Population and Age; Aged 16-64; 2012', '2012'),
#  ('Population and Age; Aged 16-64; 2013', '2013'),
#  ('Population and Age; Aged 65+; 2002', '2002'),
#  ('Population and Age; Aged 65+; 2004', '2004'),
#  ('Population and Age; Aged 65+; 2006', '2006'),
#  ('Population and Age; Aged 65+; 2008', '2008'),
#  ('Population and Age; Aged 65+; 2010', '2010'),
#  ('Population and Age; Aged 65+; 2011', '2011'),
#  ('Population and Age; Aged 65+; 2012', '2012'),
#  ('Population and Age; Aged 65+; 2013', '2013'),
#  ('Population and Age; All ages; 2002', '2002'),
#  ('Population and Age; All ages; 2004', '2004'),
#  ('Population and Age; All ages; 2006', '2006'),
#  ('Population and Age; All ages; 2008', '2008'),
#  ('Population and Age; All ages; 2010', '2010'),
#  ('Population and Age; All ages; 2011', '2011'),
#  ('Population and Age; All ages; 2012', '2012'),
#  ('Population and Age; All ages; 2013', '2013'),
#  ('Population and Age; Mean age; 2002', '2002'),
#  ('Population and Age; Mean age; 2004', '2004'),
#  ('Population and Age; Mean age; 2006', '2006'),
#  ('Population and Age; Mean age; 2008', '2008'),
#  ('Population and Age; Mean age; 2010', '2010'),
#  ('Population and Age; Mean age; 2011', '2011'),
#  ('Population and Age; Mean age; 2012', '2012'),
#  ('Population and Age; Mean age; 2013', '2013'),
#  ('Population and Age; Median age; 2002', '2002'),
#  ('Population and Age; Median age; 2004', '2004'),
#  ('Population and Age; Median age; 2006', '2006'),
#  ('Population and Age; Median age; 2008', '2008'),
#  ('Population and Age; Median age; 2010', '2010'),
#  ('Population and Age; Median age; 2011', '2011'),
#  ('Population and Age; Median age; 2012', '2012'),
#  ('Population and Age; Median age; 2013', '2013'),
#  ('Area and Density; Area; Hectares', 'Hectares'),
#  ('Area and Density; Area; Square Kilometres', 'Square Kilometres'),
#  ('Area and Density; Population density (persons per sq km); 2001 (Census)',
#   '2001 (Census)'),
#  ('Area and Density; Population density (persons per sq km); 2006', '2006'),
#  ('Area and Density; Population density (persons per sq km); 2011 (Census)',
#   '2011 (Census)'),
#  ('Area and Density; Population density (persons per sq km); 2013', '2013'),
#  ('Area and Density; Population density (persons per sq km); 2018', '2018'),
#  ('Area and Density; Population density (persons per sq km); 2023', '2023'),
#  ('Area and Density; Population density (persons per sq km); 2028', '2028'),
#  ('Diversity; Ethnic Group 5 groups - 2011 Census; White', 'White'),
#  ('Diversity; Ethnic Group 5 groups - 2011 Census; Mixed', 'Mixed'),
#  ('Diversity; Ethnic Group 5 groups - 2011 Census; Asian or Asian British',
#   'Asian or Asian British'),
#  ('Diversity; Ethnic Group 5 groups - 2011 Census; Black or Black British',
#   'Black or Black British'),
#  ('Diversity; Ethnic Group 5 groups - 2011 Census; Other', 'Other'),
#  ('Diversity; Ethnic Group 18 groups - 2011 Census; White British',
#   'White British'),
#  ('Diversity; Ethnic Group 18 groups - 2011 Census; White Irish',
#   'White Irish'),
#  ('Diversity; Ethnic Group 18 groups - 2011 Census; White Gypsy or Irish Traveller',
#   'White Gypsy or Irish Traveller'),
#  ('Diversity; Ethnic Group 18 groups - 2011 Census; Other White',
#   'Other White'),
#  ('Diversity; Ethnic Group 18 groups - 2011 Census; Mixed White and Black Caribbean',
#   'Mixed White and Black Caribbean'),
#  ('Diversity; Ethnic Group 18 groups - 2011 Census; Mixed White and Black African',
#   'Mixed White and Black African'),
#  ('Diversity; Ethnic Group 18 groups - 2011 Census; Mixed White and Asian',
#   'Mixed White and Asian'),
#  ('Diversity; Ethnic Group 18 groups - 2011 Census; Other Mixed',
#   'Other Mixed'),
#  ('Diversity; Ethnic Group 18 groups - 2011 Census; Indian', 'Indian'),
#  ('Diversity; Ethnic Group 18 groups - 2011 Census; Pakistani', 'Pakistani'),
#  ('Diversity; Ethnic Group 18 groups - 2011 Census; Bangladeshi',
#   'Bangladeshi'),
#  ('Diversity; Ethnic Group 18 groups - 2011 Census; Chinese', 'Chinese'),
#  ('Diversity; Ethnic Group 18 groups - 2011 Census; Other Asian',
#   'Other Asian'),
#  ('Diversity; Ethnic Group 18 groups - 2011 Census; Black Caribbean',
#   'Black Caribbean'),
#  ('Diversity; Ethnic Group 18 groups - 2011 Census; Black African',
#   'Black African'),
#  ('Diversity; Ethnic Group 18 groups - 2011 Census; Other Black',
#   'Other Black'),
#  ('Diversity; Ethnic Group 18 groups - 2011 Census; Arab', 'Arab'),
#  ('Diversity; Ethnic Group 18 groups - 2011 Census; Other Ethnic Group',
#   'Other Ethnic Group'),
#  ('Diversity; Religion - 2011 Census; Christian', 'Christian'),
#  ('Diversity; Religion - 2011 Census; Buddhist', 'Buddhist'),
#  ('Diversity; Religion - 2011 Census; Hindu', 'Hindu'),
#  ('Diversity; Religion - 2011 Census; Jewish', 'Jewish'),
#  ('Diversity; Religion - 2011 Census; Muslim', 'Muslim'),
#  ('Diversity; Religion - 2011 Census; Sikh', 'Sikh'),
#  ('Diversity; Religion - 2011 Census; Other religions', 'Other religions'),
#  ('Diversity; Religion - 2011 Census; No religion', 'No religion'),
#  ('Diversity; Religion - 2011 Census; Religion not stated',
#   'Religion not stated'),
#  ('Diversity; Country of Birth - 2011 Census; Born in UK', 'Born in UK'),
#  ('Diversity; Country of Birth - 2011 Census; Not Born in UK',
#   'Not Born in UK'),
#  ('Diversity; Household Language - 2011 Census; No people in household have English as a main language',
#   'No people in household have English as a main language'),
#  ('Diversity; Household Language - 2011 Census; At least 1 person in household has English as a main language',
#   'At least 1 person in household has English as a main language'),
#  ('Household composition; Household composition - 2001 Census; All Households',
#   'All Households'),
#  ('Household composition; Household composition - 2001 Census; Couple household with dependent children',
#   'Couple household with dependent children'),
#  ('Household composition; Household composition - 2001 Census; Couple household without dependent children',
#   'Couple household without dependent children'),
#  ('Household composition; Household composition - 2001 Census; Lone parent household',
#   'Lone parent household'),
#  ('Household composition; Household composition - 2001 Census; One person household',
#   'One person household'),
#  ('Household composition; Household composition - 2001 Census; Other multi person household',
#   'Other multi person household'),
#  ('Household composition; Household composition - 2011 Census; All Households',
#   'All Households'),
#  ('Household composition; Household composition - 2011 Census; Couple household with dependent children',
#   'Couple household with dependent children'),
#  ('Household composition; Household composition - 2011 Census; Couple household without dependent children',
#   'Couple household without dependent children'),
#  ('Household composition; Household composition - 2011 Census; Lone parent household',
#   'Lone parent household'),
#  ('Household composition; Household composition - 2011 Census; One person household',
#   'One person household'),
#  ('Household composition; Household composition - 2011 Census; Other multi person household',
#   'Other multi person household'),
#  ('Births and deaths; Births; 2002', '2002'),
#  ('Births and deaths; Births; 2003', '2003'),
#  ('Births and deaths; Births; 2004', '2004'),
#  ('Births and deaths; Births; 2005', '2005'),
#  ('Births and deaths; Births; 2006', '2006'),
#  ('Births and deaths; Births; 2007', '2007'),
#  ('Births and deaths; Births; 2008', '2008'),
#  ('Births and deaths; Births; 2009', '2009'),
#  ('Births and deaths; Births; 2010', '2010'),
#  ('Births and deaths; Births; 2011', '2011'),
#  ('Births and deaths; Births; 2012', '2012'),
#  ('Births and deaths; Births; 2013', '2013'),
#  ('Births and deaths; General Fertility Rate (GFR); 2002', '2002'),
#  ('Births and deaths; General Fertility Rate (GFR); 2003', '2003'),
#  ('Births and deaths; General Fertility Rate (GFR); 2004', '2004'),
#  ('Births and deaths; General Fertility Rate (GFR); 2005', '2005'),
#  ('Births and deaths; General Fertility Rate (GFR); 2006', '2006'),
#  ('Births and deaths; General Fertility Rate (GFR); 2007', '2007'),
#  ('Births and deaths; General Fertility Rate (GFR); 2008', '2008'),
#  ('Births and deaths; General Fertility Rate (GFR); 2009', '2009'),
#  ('Births and deaths; General Fertility Rate (GFR); 2010', '2010'),
#  ('Births and deaths; General Fertility Rate (GFR); 2011', '2011'),
#  ('Births and deaths; General Fertility Rate (GFR); 2012', '2012'),
#  ('Births and deaths; General Fertility Rate (GFR); 2013', '2013'),
#  ('Births and deaths; Deaths; 2002', '2002'),
#  ('Births and deaths; Deaths; 2003', '2003'),
#  ('Births and deaths; Deaths; 2004', '2004'),
#  ('Births and deaths; Deaths; 2005', '2005'),
#  ('Births and deaths; Deaths; 2006', '2006'),
#  ('Births and deaths; Deaths; 2007', '2007'),
#  ('Births and deaths; Deaths; 2008', '2008'),
#  ('Births and deaths; Deaths; 2009', '2009'),
#  ('Births and deaths; Deaths; 2010', '2010'),
#  ('Births and deaths; Deaths; 2011', '2011'),
#  ('Births and deaths; Deaths; 2012', '2012'),
#  ('Births and deaths; Deaths; 2013', '2013'),
#  ('Births and deaths; Standardised Mortality Ratio (SMR); 2002', '2002'),
#  ('Births and deaths; Standardised Mortality Ratio (SMR); 2003', '2003'),
#  ('Births and deaths; Standardised Mortality Ratio (SMR); 2004', '2004'),
#  ('Births and deaths; Standardised Mortality Ratio (SMR); 2005', '2005'),
#  ('Births and deaths; Standardised Mortality Ratio (SMR); 2006', '2006'),
#  ('Births and deaths; Standardised Mortality Ratio (SMR); 2007', '2007'),
#  ('Births and deaths; Standardised Mortality Ratio (SMR); 2008', '2008'),
#  ('Births and deaths; Standardised Mortality Ratio (SMR); 2009', '2009'),
#  ('Births and deaths; Standardised Mortality Ratio (SMR); 2010', '2010'),
#  ('Births and deaths; Standardised Mortality Ratio (SMR); 2011', '2011'),
#  ('Births and deaths; Standardised Mortality Ratio (SMR); 2012', '2012'),
#  ('Births and deaths; Standardised Mortality Ratio (SMR); 2013', '2013'),
#  ('Life Expectancy; Male life expectancy; 1999-2003', '1999-2003'),
#  ('Life Expectancy; Male life expectancy; 2000-2004', '2000-2004'),
#  ('Life Expectancy; Male life expectancy; 2001-2005', '2001-2005'),
#  ('Life Expectancy; Male life expectancy; 2002-2006', '2002-2006'),
#  ('Life Expectancy; Male life expectancy; 2003-2007', '2003-2007'),
#  ('Life Expectancy; Male life expectancy; 2004-2008', '2004-2008'),
#  ('Life Expectancy; Male life expectancy; 2005-2009', '2005-2009'),
#  ('Life Expectancy; Male life expectancy; 2006-2010', '2006-2010'),
#  ('Life Expectancy; Male life expectancy; 2007-2011', '2007-2011'),
#  ('Life Expectancy; Male life expectancy; 2008-2012', '2008-2012'),
#  ('Life Expectancy; Male life expectancy; 2009-2013', '2009-2013'),
#  ('Life Expectancy; Female life expectancy; 1999-2003', '1999-2003'),
#  ('Life Expectancy; Female life expectancy; 2000-2004', '2000-2004'),
#  ('Life Expectancy; Female life expectancy; 2001-2005', '2001-2005'),
#  ('Life Expectancy; Female life expectancy; 2002-2006', '2002-2006'),
#  ('Life Expectancy; Female life expectancy; 2003-2007', '2003-2007'),
#  ('Life Expectancy; Female life expectancy; 2004-2008', '2004-2008'),
#  ('Life Expectancy; Female life expectancy; 2005-2009', '2005-2009'),
#  ('Life Expectancy; Female life expectancy; 2006-2010', '2006-2010'),
#  ('Life Expectancy; Female life expectancy; 2007-2011', '2007-2011'),
#  ('Life Expectancy; Female life expectancy; 2008-2012', '2008-2012'),
#  ('Life Expectancy; Female life expectancy; 2009-2013', '2009-2013'),
#  ('Life Expectancy; Life expectancy at birth (all persons); 2002-2006',
#   '2002-2006'),
#  ('Life Expectancy; Life expectancy at birth (all persons); 2003-2007',
#   '2003-2007'),
#  ('Life Expectancy; Life expectancy at birth (all persons); 2004-2008',
#   '2004-2008'),
#  ('Life Expectancy; Life expectancy at birth (all persons); 2005-2009',
#   '2005-2009'),
#  ('Life Expectancy; Life expectancy at birth (all persons); 2006-2010',
#   '2006-2010'),
#  ('Life Expectancy; Life expectancy at birth (all persons); 2007-2011',
#   '2007-2011'),
#  ('Life Expectancy; Life expectancy at birth (all persons); 2008-2012',
#   '2008-2012'),
#  ('Life Expectancy; Life expectancy at birth (all persons); 2009-2013',
#   '2009-2013'),
#  ('Life Expectancy; Life expectancy at age 65 (all persons); 2002-2006',
#   '2002-2006'),
#  ('Life Expectancy; Life expectancy at age 65 (all persons); 2003-2007',
#   '2003-2007'),
#  ('Life Expectancy; Life expectancy at age 65 (all persons); 2004-2008',
#   '2004-2008'),
#  ('Life Expectancy; Life expectancy at age 65 (all persons); 2005-2009',
#   '2005-2009'),
#  ('Life Expectancy; Life expectancy at age 65 (all persons); 2006-2010',
#   '2006-2010'),
#  ('Life Expectancy; Life expectancy at age 65 (all persons); 2007-2011',
#   '2007-2011'),
#  ('Life Expectancy; Life expectancy at age 65 (all persons); 2008-2012',
#   '2008-2012'),
#  ('Life Expectancy; Life expectancy at age 65 (all persons); 2009-2013',
#   '2009-2013'),
#  ('Housing type and Tenure; All dwellings - 2011 Census; ',
#   'Unnamed: 208_level_1'),
#  ('Housing type and Tenure; All Household spaces - 2011 Census; ',
#   'Unnamed: 209_level_1'),
#  ('Housing type and Tenure; Vacant Household Spaces; Household spaces with at least one usual resident %',
#   'Household spaces with at least one usual resident %'),
#  ('Housing type and Tenure; Vacant Household Spaces; Household spaces with no usual residents %',
#   'Household spaces with no usual residents %'),
#  ('Housing type and Tenure; Accomodation Type - 2011 Census; Whole house or bungalow: Detached',
#   'Whole house or bungalow: Detached'),
#  ('Housing type and Tenure; Accomodation Type - 2011 Census; Whole house or bungalow: Semi-detached',
#   'Whole house or bungalow: Semi-detached'),
#  ('Housing type and Tenure; Accomodation Type - 2011 Census; Whole house or bungalow: Terraced',
#   'Whole house or bungalow: Terraced'),
#  ('Housing type and Tenure; Accomodation Type - 2011 Census; Flat, maisonette or apartment',
#   'Flat, maisonette or apartment'),
#  ('Housing type and Tenure; Tenure of households - 2001 Census; Owned: Owned outright',
#   'Owned: Owned outright'),
#  ('Housing type and Tenure; Tenure of households - 2001 Census; Owned: Owned with a mortgage or loan (inc shared)',
#   'Owned: Owned with a mortgage or loan (inc shared)'),
#  ('Housing type and Tenure; Tenure of households - 2001 Census; Social rented',
#   'Social rented'),
#  ('Housing type and Tenure; Tenure of households - 2001 Census; Private rented',
#   'Private rented'),
#  ('Housing type and Tenure; Tenure of households - 2001 Census; Other',
#   'Other'),
#  ('Housing type and Tenure; Tenure of households - 2011 Census; Owned: Owned outright',
#   'Owned: Owned outright'),
#  ('Housing type and Tenure; Tenure of households - 2011 Census; Owned: Owned with a mortgage or loan (inc shared)',
#   'Owned: Owned with a mortgage or loan (inc shared)'),
#  ('Housing type and Tenure; Tenure of households - 2011 Census; Social rented',
#   'Social rented'),
#  ('Housing type and Tenure; Tenure of households - 2011 Census; Private rented',
#   'Private rented'),
#  ('Housing type and Tenure; Tenure of households - 2011 Census; Rent Free',
#   'Rent Free'),
#  ('Home repossessions; Mortgage Repossession Orders - 2011; ',
#   'Unnamed: 226_level_1'),
#  ('Home repossessions; Landlord Repossession Orders - 2011; ',
#   'Unnamed: 227_level_1'),
#  ('House Prices; Median House Price; 1995', '1995'),
#  ('House Prices; Median House Price; 1996', '1996'),
#  ('House Prices; Median House Price; 1997', '1997'),
#  ('House Prices; Median House Price; 1998', '1998'),
#  ('House Prices; Median House Price; 1999', '1999'),
#  ('House Prices; Median House Price; 2000', '2000'),
#  ('House Prices; Median House Price; 2001', '2001'),
#  ('House Prices; Median House Price; 2002', '2002'),
#  ('House Prices; Median House Price; 2003', '2003'),
#  ('House Prices; Median House Price; 2004', '2004'),
#  ('House Prices; Median House Price; 2005', '2005'),
#  ('House Prices; Median House Price; 2006', '2006'),
#  ('House Prices; Median House Price; 2007', '2007'),
#  ('House Prices; Median House Price; 2008', '2008'),
#  ('House Prices; Median House Price; 2009', '2009'),
#  ('House Prices; Median House Price; 2010', '2010'),
#  ('House Prices; Median House Price; 2011', '2011'),
#  ('House Prices; Median House Price; 2012', '2012'),
#  ('House Prices; Median House Price; 2013', '2013'),
#  ('House Prices; Median House Price; 2014', '2014'),
#  ('House Prices; Number of properties sold; 2000', '2000'),
#  ('House Prices; Number of properties sold; 2001', '2001'),
#  ('House Prices; Number of properties sold; 2002', '2002'),
#  ('House Prices; Number of properties sold; 2003', '2003'),
#  ('House Prices; Number of properties sold; 2004', '2004'),
#  ('House Prices; Number of properties sold; 2005', '2005'),
#  ('House Prices; Number of properties sold; 2006', '2006'),
#  ('House Prices; Number of properties sold; 2007', '2007'),
#  ('House Prices; Number of properties sold; 2008', '2008'),
#  ('House Prices; Number of properties sold; 2009', '2009'),
#  ('House Prices; Number of properties sold; 2010', '2010'),
#  ('House Prices; Number of properties sold; 2011', '2011'),
#  ('House Prices; Number of properties sold; 2012', '2012'),
#  ('House Prices; Number of properties sold; 2013', '2013'),
#  ('House Prices; Number of properties sold; 2014', '2014'),
#  ('House Prices; % of dwellings sold during year; 2007', '2007'),
#  ('House Prices; % of dwellings sold during year; 2008', '2008'),
#  ('House Prices; % of dwellings sold during year; 2009', '2009'),
#  ('House Prices; % of dwellings sold during year; 2010', '2010'),
#  ('House Prices; % of dwellings sold during year; 2011', '2011'),
#  ('House Prices; % of dwellings sold during year; 2012', '2012'),
#  ('House Prices; % of dwellings sold during year; 2013', '2013'),
#  ('House Prices; % of dwellings sold during year; 2014', '2014'),
#  ('Dwellings and Council tax; Number of dwellings (on council tax register); 2001',
#   '2001'),
#  ('Dwellings and Council tax; Number of dwellings (on council tax register); 2002',
#   '2002'),
#  ('Dwellings and Council tax; Number of dwellings (on council tax register); 2003',
#   '2003'),
#  ('Dwellings and Council tax; Number of dwellings (on council tax register); 2004',
#   '2004'),
#  ('Dwellings and Council tax; Number of dwellings (on council tax register); 2005',
#   '2005'),
#  ('Dwellings and Council tax; Number of dwellings (on council tax register); 2006',
#   '2006'),
#  ('Dwellings and Council tax; Number of dwellings (on council tax register); 2007',
#   '2007'),
#  ('Dwellings and Council tax; Number of dwellings (on council tax register); 2008',
#   '2008'),
#  ('Dwellings and Council tax; Number of dwellings (on council tax register); 2009',
#   '2009'),
#  ('Dwellings and Council tax; Number of dwellings (on council tax register); 2010',
#   '2010'),
#  ('Dwellings and Council tax; Number of dwellings (on council tax register); 2011',
#   '2011'),
#  ('Dwellings and Council tax; Number of dwellings (on council tax register); 2012',
#   '2012'),
#  ('Dwellings and Council tax; Number of dwellings (on council tax register); 2013',
#   '2013'),
#  ('Dwellings and Council tax; Number of dwellings (on council tax register); 2014',
#   '2014'),
#  ('Dwellings and Council tax; Number of dwellings (on council tax register); 2015',
#   '2015'),
#  ('Dwellings and Council tax; % dwellings in council tax bands A or B; 2001',
#   '2001'),
#  ('Dwellings and Council tax; % dwellings in council tax bands A or B; 2002',
#   '2002'),
#  ('Dwellings and Council tax; % dwellings in council tax bands A or B; 2003',
#   '2003'),
#  ('Dwellings and Council tax; % dwellings in council tax bands A or B; 2004',
#   '2004'),
#  ('Dwellings and Council tax; % dwellings in council tax bands A or B; 2005',
#   '2005'),
#  ('Dwellings and Council tax; % dwellings in council tax bands A or B; 2006',
#   '2006'),
#  ('Dwellings and Council tax; % dwellings in council tax bands A or B; 2007',
#   '2007'),
#  ('Dwellings and Council tax; % dwellings in council tax bands A or B; 2008',
#   '2008'),
#  ('Dwellings and Council tax; % dwellings in council tax bands A or B; 2009',
#   '2009'),
#  ('Dwellings and Council tax; % dwellings in council tax bands A or B; 2010',
#   '2010'),
#  ('Dwellings and Council tax; % dwellings in council tax bands A or B; 2011',
#   '2011'),
#  ('Dwellings and Council tax; % dwellings in council tax bands A or B; 2015',
#   '2015'),
#  ('Dwellings and Council tax; % dwellings in council tax bands C, D or E; 2001',
#   '2001'),
#  ('Dwellings and Council tax; % dwellings in council tax bands C, D or E; 2002',
#   '2002'),
#  ('Dwellings and Council tax; % dwellings in council tax bands C, D or E; 2003',
#   '2003'),
#  ('Dwellings and Council tax; % dwellings in council tax bands C, D or E; 2004',
#   '2004'),
#  ('Dwellings and Council tax; % dwellings in council tax bands C, D or E; 2005',
#   '2005'),
#  ('Dwellings and Council tax; % dwellings in council tax bands C, D or E; 2006',
#   '2006'),
#  ('Dwellings and Council tax; % dwellings in council tax bands C, D or E; 2007',
#   '2007'),
#  ('Dwellings and Council tax; % dwellings in council tax bands C, D or E; 2008',
#   '2008'),
#  ('Dwellings and Council tax; % dwellings in council tax bands C, D or E; 2009',
#   '2009'),
#  ('Dwellings and Council tax; % dwellings in council tax bands C, D or E; 2010',
#   '2010'),
#  ('Dwellings and Council tax; % dwellings in council tax bands C, D or E; 2011',
#   '2011'),
#  ('Dwellings and Council tax; % dwellings in council tax bands C, D or E; 2015',
#   '2015'),
#  ('Dwellings and Council tax; % dwellings in council tax bands F, G or H; 2001',
#   '2001'),
#  ('Dwellings and Council tax; % dwellings in council tax bands F, G or H; 2002',
#   '2002'),
#  ('Dwellings and Council tax; % dwellings in council tax bands F, G or H; 2003',
#   '2003'),
#  ('Dwellings and Council tax; % dwellings in council tax bands F, G or H; 2004',
#   '2004'),
#  ('Dwellings and Council tax; % dwellings in council tax bands F, G or H; 2005',
#   '2005'),
#  ('Dwellings and Council tax; % dwellings in council tax bands F, G or H; 2006',
#   '2006'),
#  ('Dwellings and Council tax; % dwellings in council tax bands F, G or H; 2007',
#   '2007'),
#  ('Dwellings and Council tax; % dwellings in council tax bands F, G or H; 2008',
#   '2008'),
#  ('Dwellings and Council tax; % dwellings in council tax bands F, G or H; 2009',
#   '2009'),
#  ('Dwellings and Council tax; % dwellings in council tax bands F, G or H; 2010',
#   '2010'),
#  ('Dwellings and Council tax; % dwellings in council tax bands F, G or H; 2011',
#   '2011'),
#  ('Dwellings and Council tax; % dwellings in council tax bands F, G or H; 2015',
#   '2015'),
#  ('Property Type; All properties (2015); ', 'Unnamed: 322_level_1'),
#  ('Property Type; Bungalow (2015); ', 'Unnamed: 323_level_1'),
#  ('Property Type; Flat (2015); ', 'Unnamed: 324_level_1'),
#  ('Property Type; Terraced (2015); ', 'Unnamed: 325_level_1'),
#  ('Property Type; Semi-detached (2015); ', 'Unnamed: 326_level_1'),
#  ('Property Type; Detached (2015); ', 'Unnamed: 327_level_1'),
#  ('Size of dwellings (number of bedrooms); 1 bedroom; ',
#   'Unnamed: 328_level_1'),
#  ('Size of dwellings (number of bedrooms); 2 bedrooms; ',
#   'Unnamed: 329_level_1'),
#  ('Size of dwellings (number of bedrooms); 3 bedrooms; ',
#   'Unnamed: 330_level_1'),
#  ('Size of dwellings (number of bedrooms); 4+ bedrooms; ',
#   'Unnamed: 331_level_1'),
#  ('Size of dwellings (number of bedrooms); Annex/Other/Unknown; ',
#   'Unnamed: 332_level_1'),
#  ('Property build period; All properties (2015); ', 'Unnamed: 333_level_1'),
#  ('Property build period; PRE_1900; ', 'Unnamed: 334_level_1'),
#  ('Property build period; 1900_1918; ', 'Unnamed: 335_level_1'),
#  ('Property build period; 1919_1929; ', 'Unnamed: 336_level_1'),
#  ('Property build period; 1930_1939; ', 'Unnamed: 337_level_1'),
#  ('Property build period; 1945_1954; ', 'Unnamed: 338_level_1'),
#  ('Property build period; 1955_1964; ', 'Unnamed: 339_level_1'),
#  ('Property build period; 1965_1972; ', 'Unnamed: 340_level_1'),
#  ('Property build period; 1973_1982; ', 'Unnamed: 341_level_1'),
#  ('Property build period; 1983_1992; ', 'Unnamed: 342_level_1'),
#  ('Property build period; 1993_1999; ', 'Unnamed: 343_level_1'),
#  ('Property build period; 2000_2009; ', 'Unnamed: 344_level_1'),
#  ('Property build period; 2010_2015; ', 'Unnamed: 345_level_1'),
#  ('Property build period; UNKNOWN; ', 'Unnamed: 346_level_1'),
#  ('Household Income; Median Modelled Household income (£); 2001/02',
#   '2001/02'),
#  ('Household Income; Median Modelled Household income (£); 2007/08',
#   '2007/08'),
#  ('Household Income; Median Modelled Household income (£); 2012/13',
#   '2012/13'),
#  ('Household Income; Mean Modelled Household income (£); 2001/02', '2001/02'),
#  ('Household Income; Mean Modelled Household income (£); 2007/08', '2007/08'),
#  ('Household Income; Mean Modelled Household income (£); 2012/13', '2012/13'),
#  ('Employment; Economic Activity (Numbers) - 2001 Census; Economically active: Total',
#   'Economically active: Total'),
#  ('Employment; Economic Activity (Numbers) - 2001 Census; In employment (16-74)',
#   'In employment (16-74)'),
#  ('Employment; Economic Activity (Percentages) - 2001 Census; Employment rate (16-74)',
#   'Employment rate (16-74)'),
#  ('Employment; Economic Activity (Percentages) - 2001 Census; Economically active %',
#   'Economically active %'),
#  ('Employment; Economic Activity (Percentages) - 2001 Census; Economically Inactive %',
#   'Economically Inactive %'),
#  ('Employment; Economic Activity (Percentages) - 2001 Census; Economically active: % In employment',
#   'Economically active: % In employment'),
#  ('Employment; Economic Activity (Percentages) - 2001 Census; Economically active: % Unemployed',
#   'Economically active: % Unemployed'),
#  ('Employment; Economic Activity (Percentages) - 2001 Census; Aged 16 to 24: % Unemployed',
#   'Aged 16 to 24: % Unemployed'),
#  ('Employment; Economic Activity (Numbers) - 2011 Census; Economically active: Total',
#   'Economically active: Total'),
#  ('Employment; Economic Activity (Numbers) - 2011 Census; In employment (16-74)',
#   'In employment (16-74)'),
#  ('Employment; Economic Activity (Numbers) - 2011 Census; In employment (16-64)',
#   'In employment (16-64)'),
#  ('Employment; Economic Activity (Percentages) - 2011 Census; Employment rate (16-74)',
#   'Employment rate (16-74)'),
#  ('Employment; Economic Activity (Percentages) - 2011 Census; Employment rate (16-64)',
#   'Employment rate (16-64)'),
#  ('Employment; Economic Activity (Percentages) - 2011 Census; Economically active %',
#   'Economically active %'),
#  ('Employment; Economic Activity (Percentages) - 2011 Census; Economically Inactive %',
#   'Economically Inactive %'),
#  ('Employment; Economic Activity (Percentages) - 2011 Census; Economically active: % In employment',
#   'Economically active: % In employment'),
#  ('Employment; Economic Activity (Percentages) - 2011 Census; Economically active: % Unemployed',
#   'Economically active: % Unemployed'),
#  ('Employment; Economic Activity (Percentages) - 2011 Census; Aged 16 to 24: % Unemployed',
#   'Aged 16 to 24: % Unemployed'),
#  ('Employment; Adults not in Employment - 2011 Census; No adults in employment in household: With dependent children',
#   'No adults in employment in household: With dependent children'),
#  ('Employment; Adults not in Employment - 2011 Census; % of households with no adults in employment with dependent children',
#   '% of households with no adults in employment with dependent children'),
#  ('Employment; Lone Parent Not in Employment - 2011 Census; All lone parent housholds with dependent children',
#   'All lone parent housholds with dependent children'),
#  ('Employment; Lone Parent Not in Employment - 2011 Census; Lone parent not in employment Total',
#   'Lone parent not in employment Total'),
#  ('Employment; Lone Parent Not in Employment - 2011 Census; Lone parent not in employment %',
#   'Lone parent not in employment %'),
#  ('Qualifications; Qualifications and Students - 2011 Census; % No qualifications',
#   '% No qualifications'),
#  ('Qualifications; Qualifications and Students - 2011 Census; % Highest level of qualification: Level 1 qualifications',
#   '% Highest level of qualification: Level 1 qualifications'),
#  ('Qualifications; Qualifications and Students - 2011 Census; % Highest level of qualification: Level 2 qualifications',
#   '% Highest level of qualification: Level 2 qualifications'),
#  ('Qualifications; Qualifications and Students - 2011 Census; % Highest level of qualification: Apprenticeship',
#   '% Highest level of qualification: Apprenticeship'),
#  ('Qualifications; Qualifications and Students - 2011 Census; % Highest level of qualification: Level 3 qualifications',
#   '% Highest level of qualification: Level 3 qualifications'),
#  ('Qualifications; Qualifications and Students - 2011 Census; % Highest level of qualification: Level 4 qualifications and above',
#   '% Highest level of qualification: Level 4 qualifications and above'),
#  ('Qualifications; Qualifications and Students - 2011 Census; % Highest level of qualification: Other qualifications',
#   '% Highest level of qualification: Other qualifications'),
#  ('Qualifications; Qualifications and Students - 2011 Census; % of 16+ who are schoolchildren and full-time students: Age 18 and over',
#   '% of 16+ who are schoolchildren and full-time students: Age 18 and over'),
#  ('Benefits claimants; DWP Working-age client group (numbers); 2007', '2007'),
#  ('Benefits claimants; DWP Working-age client group (numbers); 2008', '2008'),
#  ('Benefits claimants; DWP Working-age client group (numbers); 2009', '2009'),
#  ('Benefits claimants; DWP Working-age client group (numbers); 2010', '2010'),
#  ('Benefits claimants; DWP Working-age client group (numbers); 2011', '2011'),
#  ('Benefits claimants; DWP Working-age client group (numbers); 2012', '2012'),
#  ('Benefits claimants; DWP Working-age client group (numbers); 2013', '2013'),
#  ('Benefits claimants; DWP Working-age client group (numbers); 2014', '2014'),
#  ('Benefits claimants; DWP Working-age client group (rates); 2007', '2007'),
#  ('Benefits claimants; DWP Working-age client group (rates); 2008', '2008'),
#  ('Benefits claimants; DWP Working-age client group (rates); 2009', '2009'),
#  ('Benefits claimants; DWP Working-age client group (rates); 2010', '2010'),
#  ('Benefits claimants; DWP Working-age client group (rates); 2011', '2011'),
#  ('Benefits claimants; DWP Working-age client group (rates); 2012', '2012'),
#  ('Benefits claimants; DWP Working-age client group (rates); 2013', '2013'),
#  ('Benefits claimants; DWP Working-age client group (rates); 2014', '2014'),
#  ('Benefits claimants; Housing Benefit claimants; 2011', '2011'),
#  ('Benefits claimants; Housing Benefit claimants; 2012', '2012'),
#  ('Benefits claimants; Housing Benefit claimants; 2013', '2013'),
#  ('Benefits claimants; Housing Benefit claimants; 2014', '2014'),
#  ('Benefits claimants; Housing Benefit claimants; 2015', '2015'),
#  ('Benefits claimants; Housing Benefit rates; 2011', '2011'),
#  ('Benefits claimants; Housing Benefit rates; 2012', '2012'),
#  ('Benefits claimants; Housing Benefit rates; 2013', '2013'),
#  ('Benefits claimants; Housing Benefit rates; 2014', '2014'),
#  ('Benefits claimants; Housing Benefit rates; 2015', '2015'),
#  ('Benefits claimants; Incapacity Benefit Claimants; 2000', '2000'),
#  ('Benefits claimants; Incapacity Benefit Claimants; 2001', '2001'),
#  ('Benefits claimants; Incapacity Benefit Claimants; 2002', '2002'),
#  ('Benefits claimants; Incapacity Benefit Claimants; 2003', '2003'),
#  ('Benefits claimants; Incapacity Benefit Claimants; 2004', '2004'),
#  ('Benefits claimants; Incapacity Benefit Claimants; 2005', '2005'),
#  ('Benefits claimants; Incapacity Benefit Claimants; 2006', '2006'),
#  ('Benefits claimants; Incapacity Benefit Claimants; 2007', '2007'),
#  ('Benefits claimants; Incapacity Benefit Claimants; 2008', '2008'),
#  ('Benefits claimants; Incapacity Benefit Claimants; 2009', '2009'),
#  ('Benefits claimants; Incapacity Benefit Claimants; 2010', '2010'),
#  ('Benefits claimants; Incapacity Benefit Claimants; 2011', '2011'),
#  ('Benefits claimants; Incapacity Benefit Claimants; 2012', '2012'),
#  ('Benefits claimants; Incapacity Benefit Claimants; 2013', '2013'),
#  ('Benefits claimants; Incapacity Benefit Claimants; 2014', '2014'),
#  ('Benefits claimants; Income Support Claimants; 2000', '2000'),
#  ('Benefits claimants; Income Support Claimants; 2001', '2001'),
#  ('Benefits claimants; Income Support Claimants; 2002', '2002'),
#  ('Benefits claimants; Income Support Claimants; 2003', '2003'),
#  ('Benefits claimants; Income Support Claimants; 2004', '2004'),
#  ('Benefits claimants; Income Support Claimants; 2005', '2005'),
#  ('Benefits claimants; Income Support Claimants; 2006', '2006'),
#  ('Benefits claimants; Income Support Claimants; 2007', '2007'),
#  ('Benefits claimants; Income Support Claimants; 2008', '2008'),
#  ('Benefits claimants; Income Support Claimants; 2009', '2009'),
#  ('Benefits claimants; Income Support Claimants; 2010', '2010'),
#  ('Benefits claimants; Income Support Claimants; 2011', '2011'),
#  ('Benefits claimants; Income Support Claimants; 2012', '2012'),
#  ('Benefits claimants; Income Support Claimants; 2013', '2013'),
#  ('Benefits claimants; Income Support Claimants; 2014', '2014'),
#  ('Benefits claimants; Employment and support allowance claimants; 2009',
#   '2009'),
#  ('Benefits claimants; Employment and support allowance claimants; 2010',
#   '2010'),
#  ('Benefits claimants; Employment and support allowance claimants; 2011',
#   '2011'),
#  ('Benefits claimants; Employment and support allowance claimants; 2012',
#   '2012'),
#  ('Benefits claimants; Employment and support allowance claimants; 2013',
#   '2013'),
#  ('Benefits claimants; Employment and support allowance claimants; 2014',
#   '2014'),
#  ('Jobseekers Allowance; Total JSA Claimants; 2000', '2000'),
#  ('Jobseekers Allowance; Total JSA Claimants; 2001', '2001'),
#  ('Jobseekers Allowance; Total JSA Claimants; 2002', '2002'),
#  ('Jobseekers Allowance; Total JSA Claimants; 2003', '2003'),
#  ('Jobseekers Allowance; Total JSA Claimants; 2004', '2004'),
#  ('Jobseekers Allowance; Total JSA Claimants; 2005', '2005'),
#  ('Jobseekers Allowance; Total JSA Claimants; 2006', '2006'),
#  ('Jobseekers Allowance; Total JSA Claimants; 2007', '2007'),
#  ('Jobseekers Allowance; Total JSA Claimants; 2008', '2008'),
#  ('Jobseekers Allowance; Total JSA Claimants; 2009', '2009'),
#  ('Jobseekers Allowance; Total JSA Claimants; 2010', '2010'),
#  ('Jobseekers Allowance; Total JSA Claimants; 2011', '2011'),
#  ('Jobseekers Allowance; Total JSA Claimants; 2012', '2012'),
#  ('Jobseekers Allowance; Total JSA Claimants; 2013', '2013'),
#  ('Jobseekers Allowance; Total JSA Claimants; 2014', '2014'),
#  ('Jobseekers Allowance; Total JSA Claimants; 2015', '2015'),
#  ('Jobseekers Allowance; JSA Claimant Rate; 2011', '2011'),
#  ('Jobseekers Allowance; JSA Claimant Rate; 2012', '2012'),
#  ('Jobseekers Allowance; JSA Claimant Rate; 2013', '2013'),
#  ('Jobseekers Allowance; JSA Claimant Rate; 2014', '2014'),
#  ('Jobseekers Allowance; JSA Claimant Rate; 2015', '2015'),
#  ('Jobseekers Allowance; Male JSA Claimants; 2000', '2000'),
#  ('Jobseekers Allowance; Male JSA Claimants; 2001', '2001'),
#  ('Jobseekers Allowance; Male JSA Claimants; 2002', '2002'),
#  ('Jobseekers Allowance; Male JSA Claimants; 2003', '2003'),
#  ('Jobseekers Allowance; Male JSA Claimants; 2004', '2004'),
#  ('Jobseekers Allowance; Male JSA Claimants; 2005', '2005'),
#  ('Jobseekers Allowance; Male JSA Claimants; 2006', '2006'),
#  ('Jobseekers Allowance; Male JSA Claimants; 2007', '2007'),
#  ('Jobseekers Allowance; Male JSA Claimants; 2008', '2008'),
#  ('Jobseekers Allowance; Male JSA Claimants; 2009', '2009'),
#  ('Jobseekers Allowance; Male JSA Claimants; 2010', '2010'),
#  ('Jobseekers Allowance; Male JSA Claimants; 2011', '2011'),
#  ('Jobseekers Allowance; Male JSA Claimants; 2012', '2012'),
#  ('Jobseekers Allowance; Male JSA Claimants; 2013', '2013'),
#  ('Jobseekers Allowance; Male JSA Claimants; 2014', '2014'),
#  ('Jobseekers Allowance; Male JSA Claimants; 2015', '2015'),
#  ('Jobseekers Allowance; Female JSA Claimants; 2000', '2000'),
#  ('Jobseekers Allowance; Female JSA Claimants; 2001', '2001'),
#  ('Jobseekers Allowance; Female JSA Claimants; 2002', '2002'),
#  ('Jobseekers Allowance; Female JSA Claimants; 2003', '2003'),
#  ('Jobseekers Allowance; Female JSA Claimants; 2004', '2004'),
#  ('Jobseekers Allowance; Female JSA Claimants; 2005', '2005'),
#  ('Jobseekers Allowance; Female JSA Claimants; 2006', '2006'),
#  ('Jobseekers Allowance; Female JSA Claimants; 2007', '2007'),
#  ('Jobseekers Allowance; Female JSA Claimants; 2008', '2008'),
#  ('Jobseekers Allowance; Female JSA Claimants; 2009', '2009'),
#  ('Jobseekers Allowance; Female JSA Claimants; 2010', '2010'),
#  ('Jobseekers Allowance; Female JSA Claimants; 2011', '2011'),
#  ('Jobseekers Allowance; Female JSA Claimants; 2012', '2012'),
#  ('Jobseekers Allowance; Female JSA Claimants; 2013', '2013'),
#  ('Jobseekers Allowance; Female JSA Claimants; 2014', '2014'),
#  ('Jobseekers Allowance; Female JSA Claimants; 2015', '2015'),
#  ('Jobseekers Allowance; JSA Claimants Aged 16-24; 2000', '2000'),
#  ('Jobseekers Allowance; JSA Claimants Aged 16-24; 2001', '2001'),
#  ('Jobseekers Allowance; JSA Claimants Aged 16-24; 2002', '2002'),
#  ('Jobseekers Allowance; JSA Claimants Aged 16-24; 2003', '2003'),
#  ('Jobseekers Allowance; JSA Claimants Aged 16-24; 2004', '2004'),
#  ('Jobseekers Allowance; JSA Claimants Aged 16-24; 2005', '2005'),
#  ('Jobseekers Allowance; JSA Claimants Aged 16-24; 2006', '2006'),
#  ('Jobseekers Allowance; JSA Claimants Aged 16-24; 2007', '2007'),
#  ('Jobseekers Allowance; JSA Claimants Aged 16-24; 2008', '2008'),
#  ('Jobseekers Allowance; JSA Claimants Aged 16-24; 2009', '2009'),
#  ('Jobseekers Allowance; JSA Claimants Aged 16-24; 2010', '2010'),
#  ('Jobseekers Allowance; JSA Claimants Aged 16-24; 2011', '2011'),
#  ('Jobseekers Allowance; JSA Claimants Aged 16-24; 2012', '2012'),
#  ('Jobseekers Allowance; JSA Claimants Aged 16-24; 2013', '2013'),
#  ('Jobseekers Allowance; JSA Claimants Aged 16-24; 2014', '2014'),
#  ('Jobseekers Allowance; JSA Claimants Aged 16-24; 2015', '2015'),
#  ('Out-of-Work Families; Numbers children (0-18) living in Out-of-work Benefit Claimant Households; 2010',
#   '2010'),
#  ('Out-of-Work Families; Numbers children (0-18) living in Out-of-work Benefit Claimant Households; 2011',
#   '2011'),
#  ('Out-of-Work Families; Numbers children (0-18) living in Out-of-work Benefit Claimant Households; 2012',
#   '2012'),
#  ('Out-of-Work Families; Numbers children (0-18) living in Out-of-work Benefit Claimant Households; 2013',
#   '2013'),
#  ('Out-of-Work Families; Numbers children (0-18) living in Out-of-work Benefit Claimant Households; 2014',
#   '2014'),
#  ('Out-of-Work Families; Rates children (0-18) living in Out-of-work Benefit Claimant Households; 2010',
#   '2010'),
#  ('Out-of-Work Families; Rates children (0-18) living in Out-of-work Benefit Claimant Households; 2011',
#   '2011'),
#  ('Out-of-Work Families; Rates children (0-18) living in Out-of-work Benefit Claimant Households; 2012',
#   '2012'),
#  ('Out-of-Work Families; Rates children (0-18) living in Out-of-work Benefit Claimant Households; 2013',
#   '2013'),
#  ('Out-of-Work Families; Rates children (0-18) living in Out-of-work Benefit Claimant Households; 2014',
#   '2014'),
#  ('Out-of-Work Families; Children aged 0-18 (2014); ', 'Unnamed: 525_level_1'),
#  ('Children in Poverty; % of children aged under 16 in poverty; 2006', '2006'),
#  ('Children in Poverty; % of children aged under 16 in poverty; 2007', '2007'),
#  ('Children in Poverty; % of children aged under 16 in poverty; 2008', '2008'),
#  ('Children in Poverty; % of children aged under 16 in poverty; 2009', '2009'),
#  ('Children in Poverty; % of children aged under 16 in poverty; 2010', '2010'),
#  ('Children in Poverty; % of children aged under 16 in poverty; 2011', '2011'),
#  ('Children in Poverty; % of children aged under 16 in poverty; 2012', '2012'),
#  ('GCSE; Average GCSE capped point scores; 2005', '2005'),
#  ('GCSE; Average GCSE capped point scores; 2006', '2006'),
#  ('GCSE; Average GCSE capped point scores; 2007', '2007'),
#  ('GCSE; Average GCSE capped point scores; 2008', '2008'),
#  ('GCSE; Average GCSE capped point scores; 2009', '2009'),
#  ('GCSE; Average GCSE capped point scores; 2010', '2010'),
#  ('GCSE; Average GCSE capped point scores; 2011', '2011'),
#  ('GCSE; Average GCSE capped point scores; 2012', '2012'),
#  ('GCSE; Average GCSE capped point scores; 2013', '2013'),
#  ('GCSE; Average GCSE capped point scores; 2014', '2014'),
#  ('A-Level Point Scores; Average Point Score Per Student; 2013', '2013'),
#  ('A-Level Point Scores; Average Point Score Per Student; 2014', '2014'),
#  ('A-Level Point Scores; Average Point Score Per Entry; All Students; 2013',
#   '2013'),
#  ('A-Level Point Scores; Average Point Score Per Entry; All Students; 2014',
#   '2014'),
#  ('Pupil Absence; Overall Absence in All Schools (%); 2007', '2007'),
#  ('Pupil Absence; Overall Absence in All Schools (%); 2008', '2008'),
#  ('Pupil Absence; Overall Absence in All Schools (%); 2009', '2009'),
#  ('Pupil Absence; Overall Absence in All Schools (%); 2010', '2010'),
#  ('Pupil Absence; Overall Absence in All Schools (%); 2011', '2011'),
#  ('Pupil Absence; Overall Absence in All Schools (%); 2012', '2012'),
#  ('Pupil Absence; Overall Absence in All Schools (%); 2013', '2013'),
#  ('Pupil Absence; Authorised Absence in All Schools (%); 2007', '2007'),
#  ('Pupil Absence; Authorised Absence in All Schools (%); 2008', '2008'),
#  ('Pupil Absence; Authorised Absence in All Schools (%); 2009', '2009'),
#  ('Pupil Absence; Authorised Absence in All Schools (%); 2010', '2010'),
#  ('Pupil Absence; Authorised Absence in All Schools (%); 2011', '2011'),
#  ('Pupil Absence; Authorised Absence in All Schools (%); 2012', '2012'),
#  ('Pupil Absence; Authorised Absence in All Schools (%); 2013', '2013'),
#  ('Pupil Absence; Unauthorised Absence in All Schools (%); 2007', '2007'),
#  ('Pupil Absence; Unauthorised Absence in All Schools (%); 2008', '2008'),
#  ('Pupil Absence; Unauthorised Absence in All Schools (%); 2009', '2009'),
#  ('Pupil Absence; Unauthorised Absence in All Schools (%); 2010', '2010'),
#  ('Pupil Absence; Unauthorised Absence in All Schools (%); 2011', '2011'),
#  ('Pupil Absence; Unauthorised Absence in All Schools (%); 2012', '2012'),
#  ('Pupil Absence; Unauthorised Absence in All Schools (%); 2013', '2013'),
#  ('Crime; Burglary, Burglary In A Dwelling (2014); ', 'Unnamed: 568_level_1'),
#  ('Crime; Burglary, Burglary In Other Buildings (2014); ',
#   'Unnamed: 569_level_1'),
#  ('Crime; Criminal Damage, Criminal Damage To Dwelling (2014); ',
#   'Unnamed: 570_level_1'),
#  ('Crime; Criminal Damage, Criminal Damage To Motor Vehicle (2014); ',
#   'Unnamed: 571_level_1'),
#  ('Crime; Criminal Damage, Criminal Damage To Other Building (2014); ',
#   'Unnamed: 572_level_1'),
#  ('Crime; Drugs, Drug Trafficking (2014); ', 'Unnamed: 573_level_1'),
#  ('Crime; Drugs, Possession Of Drugs (2014); ', 'Unnamed: 574_level_1'),
#  ('Crime; Robbery, Business Property (2014); ', 'Unnamed: 575_level_1'),
#  ('Crime; Robbery, Personal Property (2014); ', 'Unnamed: 576_level_1'),
#  ('Crime; Sexual Offences, Rape (2014); ', 'Unnamed: 577_level_1'),
#  ('Crime; Theft & Handling, Handling Stolen Goods (2014); ',
#   'Unnamed: 578_level_1'),
#  ('Crime; Theft & Handling, Motor Vehicle Interference & Tampering (2014); ',
#   'Unnamed: 579_level_1'),
#  ('Crime; Theft & Handling, Theft From Motor Vehicle (2014); ',
#   'Unnamed: 580_level_1'),
#  ('Crime; Theft & Handling, Theft From Shops (2014); ',
#   'Unnamed: 581_level_1'),
#  ('Crime; Theft & Handling, Theft/Taking Of Motor Vehicle (2014); ',
#   'Unnamed: 582_level_1'),
#  ('Crime; Theft & Handling, Theft/Taking Of Pedal Cycle (2014); ',
#   'Unnamed: 583_level_1'),
#  ('Crime; Violence Against The Person, Assault With Injury (2014); ',
#   'Unnamed: 584_level_1'),
#  ('Crime; Violence Against The Person, Common Assault (2014); ',
#   'Unnamed: 585_level_1'),
#  ('Crime; Violence Against The Person, Harassment (2014); ',
#   'Unnamed: 586_level_1'),
#  ('Crime; Violence Against The Person, Offensive Weapon (2014); ',
#   'Unnamed: 587_level_1'),
#  ('Crime; Violence Against The Person, Wounding/GBH (2014); ',
#   'Unnamed: 588_level_1'),
#  ('Crime; Total crime rate; 2001/02', '2001/02'),
#  ('Crime; Total crime rate; 2002/03', '2002/03'),
#  ('Crime; Total crime rate; 2003/04', '2003/04'),
#  ('Crime; Total crime rate; 2004/05', '2004/05'),
#  ('Crime; Total crime rate; 2005/06', '2005/06'),
#  ('Crime; Total crime rate; 2006/07', '2006/07'),
#  ('Crime; Total crime rate; 2007/08', '2007/08'),
#  ('Crime; Total crime rate; 2008/09', '2008/09'),
#  ('Crime; Total crime rate; 2009/10', '2009/10'),
#  ('Crime; Total crime rate; 2010/11', '2010/11'),
#  ('Crime; Total crime rate; 2011/12', '2011/12'),
#  ('Crime; Total crime rate; 2012/13', '2012/13'),
#  ('Crime; Total crime rate; 2013/14', '2013/14'),
#  ('Crime; Total crime rate; 2014/15', '2014/15'),
#  ('Crime; Total crime (numbers); 2001/02', '2001/02'),
#  ('Crime; Total crime (numbers); 2002/03', '2002/03'),
#  ('Crime; Total crime (numbers); 2003/04', '2003/04'),
#  ('Crime; Total crime (numbers); 2004/05', '2004/05'),
#  ('Crime; Total crime (numbers); 2005/06', '2005/06'),
#  ('Crime; Total crime (numbers); 2006/07', '2006/07'),
#  ('Crime; Total crime (numbers); 2007/08', '2007/08'),
#  ('Crime; Total crime (numbers); 2008/09', '2008/09'),
#  ('Crime; Total crime (numbers); 2009/10', '2009/10'),
#  ('Crime; Total crime (numbers); 2010/11', '2010/11'),
#  ('Crime; Total crime (numbers); 2011/12', '2011/12'),
#  ('Crime; Total crime (numbers); 2012/13', '2012/13'),
#  ('Crime; Total crime (numbers); 2013/14', '2013/14'),
#  ('Crime; Total crime (numbers); 2014/15', '2014/15'),
#  ('Crime; Violence against the person; 2001/02', '2001/02'),
#  ('Crime; Violence against the person; 2002/03', '2002/03'),
#  ('Crime; Violence against the person; 2003/04', '2003/04'),
#  ('Crime; Violence against the person; 2004/05', '2004/05'),
#  ('Crime; Violence against the person; 2005/06', '2005/06'),
#  ('Crime; Violence against the person; 2006/07', '2006/07'),
#  ('Crime; Violence against the person; 2007/08', '2007/08'),
#  ('Crime; Violence against the person; 2008/09', '2008/09'),
#  ('Crime; Violence against the person; 2009/10', '2009/10'),
#  ('Crime; Violence against the person; 2010/11', '2010/11'),
#  ('Crime; Violence against the person; 2011/12', '2011/12'),
#  ('Crime; Violence against the person; 2012/13', '2012/13'),
# ...
#  ('Crime; Criminal Damage; 2011/12', '2011/12'),
#  ('Crime; Criminal Damage; 2012/13', '2012/13'),
#  ('Crime; Criminal Damage; 2013/14', '2013/14'),
#  ('Crime; Criminal Damage; 2014/15', '2014/15'),
#  ('Crime; Drugs; 2001/02', '2001/02'),
#  ('Crime; Drugs; 2002/03', '2002/03'),
#  ('Crime; Drugs; 2003/04', '2003/04'),
#  ('Crime; Drugs; 2004/05', '2004/05'),
#  ('Crime; Drugs; 2005/06', '2005/06'),
#  ('Crime; Drugs; 2006/07', '2006/07'),
#  ('Crime; Drugs; 2007/08', '2007/08'),
#  ('Crime; Drugs; 2008/09', '2008/09'),
#  ('Crime; Drugs; 2009/10', '2009/10'),
#  ('Crime; Drugs; 2010/11', '2010/11'),
#  ('Crime; Drugs; 2011/12', '2011/12'),
#  ('Crime; Drugs; 2012/13', '2012/13'),
#  ('Crime; Drugs; 2013/14', '2013/14'),
#  ('Crime; Drugs; 2014/15', '2014/15'),
#  ('Crime; Other Notifiable Offences; 2001/02', '2001/02'),
#  ('Crime; Other Notifiable Offences; 2002/03', '2002/03'),
#  ('Crime; Other Notifiable Offences; 2003/04', '2003/04'),
#  ('Crime; Other Notifiable Offences; 2004/05', '2004/05'),
#  ('Crime; Other Notifiable Offences; 2005/06', '2005/06'),
#  ('Crime; Other Notifiable Offences; 2006/07', '2006/07'),
#  ('Crime; Other Notifiable Offences; 2007/08', '2007/08'),
#  ('Crime; Other Notifiable Offences; 2008/09', '2008/09'),
#  ('Crime; Other Notifiable Offences; 2009/10', '2009/10'),
#  ('Crime; Other Notifiable Offences; 2010/11', '2010/11'),
#  ('Crime; Other Notifiable Offences; 2011/12', '2011/12'),
#  ('Crime; Other Notifiable Offences; 2011/13', '2011/13'),
#  ('Crime; Other Notifiable Offences; 2013/14', '2013/14'),
#  ('Crime; Other Notifiable Offences; 2014/15', '2014/15'),
#  ('Fires; Deliberate Fires; 2005', '2005'),
#  ('Fires; Deliberate Fires; 2006', '2006'),
#  ('Fires; Deliberate Fires; 2007', '2007'),
#  ('Fires; Deliberate Fires; 2008', '2008'),
#  ('Fires; Deliberate Fires; 2009', '2009'),
#  ('Fires; Deliberate Fires; 2010', '2010'),
#  ('Fires; Deliberate Fires; 2011', '2011'),
#  ('Fires; Deliberate Fires; 2012', '2012'),
#  ('Fires; Deliberate Fires; 2013', '2013'),
#  ('Fires; Deliberate Fires; 2014', '2014'),
#  ('Fires; Deliberate Fires per 1,000 population; 2005', '2005'),
#  ('Fires; Deliberate Fires per 1,000 population; 2006', '2006'),
#  ('Fires; Deliberate Fires per 1,000 population; 2007', '2007'),
#  ('Fires; Deliberate Fires per 1,000 population; 2008', '2008'),
#  ('Fires; Deliberate Fires per 1,000 population; 2009', '2009'),
#  ('Fires; Deliberate Fires per 1,000 population; 2010', '2010'),
#  ('Fires; Deliberate Fires per 1,000 population; 2011', '2011'),
#  ('Fires; Deliberate Fires per 1,000 population; 2012', '2012'),
#  ('Fires; Deliberate Fires per 1,000 population; 2013', '2013'),
#  ('Fires; Deliberate Fires per 1,000 population; 2014', '2014'),
#  ('Ambulance; All Ambulance Incidents; 2006', '2006'),
#  ('Ambulance; All Ambulance Incidents; 2007', '2007'),
#  ('Ambulance; All Ambulance Incidents; 2008', '2008'),
#  ('Ambulance; All Ambulance Incidents; 2009', '2009'),
#  ('Ambulance; All Ambulance Incidents; 2010', '2010'),
#  ('Ambulance; All Ambulance Incidents; 2011', '2011'),
#  ('Ambulance; All Ambulance Incidents; 2012', '2012'),
#  ('Ambulance; All Ambulance Incidents; 2013', '2013'),
#  ('Ambulance; All Ambulance Incidents; 2014', '2014'),
#  ('Ambulance; Assault Incidents attended by Ambulance; 2006', '2006'),
#  ('Ambulance; Assault Incidents attended by Ambulance; 2007', '2007'),
#  ('Ambulance; Assault Incidents attended by Ambulance; 2008', '2008'),
#  ('Ambulance; Assault Incidents attended by Ambulance; 2009', '2009'),
#  ('Ambulance; Assault Incidents attended by Ambulance; 2010', '2010'),
#  ('Ambulance; Assault Incidents attended by Ambulance; 2011', '2011'),
#  ('Ambulance; Assault Incidents attended by Ambulance; 2012', '2012'),
#  ('Ambulance; Assault Incidents attended by Ambulance; 2013', '2013'),
#  ('Ambulance; Assault Incidents attended by Ambulance; 2014', '2014'),
#  ('Ambulance; Animal Attack Incidents; 2006', '2006'),
#  ('Ambulance; Animal Attack Incidents; 2007', '2007'),
#  ('Ambulance; Animal Attack Incidents; 2008', '2008'),
#  ('Ambulance; Animal Attack Incidents; 2009', '2009'),
#  ('Ambulance; Animal Attack Incidents; 2010', '2010'),
#  ('Ambulance; Animal Attack Incidents; 2011', '2011'),
#  ('Ambulance; Animal Attack Incidents; 2012', '2012'),
#  ('Ambulance; Animal Attack Incidents; 2013', '2013'),
#  ('Ambulance; Animal Attack Incidents; 2014', '2014'),
#  ('Ambulance; All weapon injuries; 2006', '2006'),
#  ('Ambulance; All weapon injuries; 2007', '2007'),
#  ('Ambulance; All weapon injuries; 2008', '2008'),
#  ('Ambulance; All weapon injuries; 2009', '2009'),
#  ('Ambulance; All weapon injuries; 2010', '2010'),
#  ('Ambulance; All weapon injuries; 2011', '2011'),
#  ('Ambulance; All weapon injuries; 2012', '2012'),
#  ('Ambulance; All weapon injuries; 2013', '2013'),
#  ('Ambulance; All weapon injuries; 2014', '2014'),
#  ('Binge Drinking; Number of ambulance call outs for alcohol related illness; 2011',
#   '2011'),
#  ('Binge Drinking; Number of ambulance call outs for alcohol related illness; 2012',
#   '2012'),
#  ('Binge Drinking; Number of ambulance call outs for alcohol related illness; 2013',
#   '2013'),
#  ('Binge Drinking; Number of ambulance call outs for alcohol related illness; 2014',
#   '2014'),
#  ('Binge Drinking; Rate of ambulance call outs for alcohol related illness; 2011',
#   '2011'),
#  ('Binge Drinking; Rate of ambulance call outs for alcohol related illness; 2012',
#   '2012'),
#  ('Binge Drinking; Rate of ambulance call outs for alcohol related illness; 2013',
#   '2013'),
#  ('Binge Drinking; Rate of ambulance call outs for alcohol related illness; 2014',
#   '2014'),
#  ('Road Casualties; Total Casualties; 2010', '2010'),
#  ('Road Casualties; Total Casualties; 2011', '2011'),
#  ('Road Casualties; Total Casualties; 2012', '2012'),
#  ('Road Casualties; Total Casualties; 2013', '2013'),
#  ('Road Casualties; Total Casualties; 2014', '2014'),
#  ('Road Casualties; Fatal; 2010', '2010'),
#  ('Road Casualties; Fatal; 2011', '2011'),
#  ('Road Casualties; Fatal; 2012', '2012'),
#  ('Road Casualties; Fatal; 2013', '2013'),
#  ('Road Casualties; Fatal; 2014', '2014'),
#  ('Road Casualties; Serious; 2010', '2010'),
#  ('Road Casualties; Serious; 2011', '2011'),
#  ('Road Casualties; Serious; 2012', '2012'),
#  ('Road Casualties; Serious; 2013', '2013'),
#  ('Road Casualties; Serious; 2014', '2014'),
#  ('Road Casualties; Slight; 2010', '2010'),
#  ('Road Casualties; Slight; 2011', '2011'),
#  ('Road Casualties; Slight; 2012', '2012'),
#  ('Road Casualties; Slight; 2013', '2013'),
#  ('Road Casualties; Slight; 2014', '2014'),
#  ('Health and Disability; General Health - 2011 Census; % People with Bad or Very Bad Health',
#   '% People with Bad or Very Bad Health'),
#  ('Health and Disability; General Health - 2011 Census; % People whose Day-to-day activities are limited a lot',
#   '% People whose Day-to-day activities are limited a lot'),
#  ('Happiness and Well-being; Subjective well-being average score, 2011/12 and 2012/13; ',
#   'Unnamed: 829_level_1'),
#  ('Childhood Obesity Prevalence; Reception (age 4-5 years); 2008/09 to 2010/11: % obese',
#   '2008/09 to 2010/11: % obese'),
#  ('Childhood Obesity Prevalence; Reception (age 4-5 years); 2009/10 to 2011/12: % obese',
#   '2009/10 to 2011/12: % obese'),
#  ('Childhood Obesity Prevalence; Reception (age 4-5 years); 2010/11 to 2012/13: % obese',
#   '2010/11 to 2012/13: % obese'),
#  ('Childhood Obesity Prevalence; Reception (age 4-5 years); 2011/12 to 2013/14: % obese',
#   '2011/12 to 2013/14: % obese'),
#  ('Childhood Obesity Prevalence; Year 6 (age 10-11); 2008/09 to 2010/11: % obese',
#   '2008/09 to 2010/11: % obese'),
#  ('Childhood Obesity Prevalence; Year 6 (age 10-11); 2009/10 to 2011/12: % obese',
#   '2009/10 to 2011/12: % obese'),
#  ('Childhood Obesity Prevalence; Year 6 (age 10-11); 2010/11 to 2012/13: % obese',
#   '2010/11 to 2012/13: % obese'),
#  ('Childhood Obesity Prevalence; Year 6 (age 10-11); 2011/12 to 2013/14: % obese',
#   '2011/12 to 2013/14: % obese'),
#  ('Air Emissions; Annual Mean of Particulate Matter (PM10); 2008', '2008'),
#  ('Air Emissions; Annual Mean of Particulate Matter (PM10); 2011', '2011'),
#  ('Air Emissions; Annual Mean of Nitrogen Oxide (NOx); 2008', '2008'),
#  ('Air Emissions; Annual Mean of Nitrogen Oxide (NOx); 2011', '2011'),
#  ('Air Emissions; Annual Mean of Nitrogen Dioxide (NO2); 2008', '2008'),
#  ('Air Emissions; Annual Mean of Nitrogen Dioxide (NO2); 2011', '2011'),
#  ('Land Use; Area of Admin Geography (Hectares); 2005', '2005'),
#  ('Land Use; % Domestic Buildings; 2005', '2005'),
#  ('Land Use; % Domestic Gardens; 2005', '2005'),
#  ('Land Use; % Non Domestic Buildings; 2005', '2005'),
#  ('Land Use; % Road; 2005', '2005'),
#  ('Land Use; % Rail; 2005', '2005'),
#  ('Land Use; % Path; 2005', '2005'),
#  ('Land Use; % Greenspace; 2005', '2005'),
#  ('Land Use; % Water; 2005', '2005'),
#  ('Land Use; % Other Land Uses; 2005', '2005'),
#  ('Access to green space and nature; % homes with access to:; Local, Small or Pocket Park',
#   'Local, Small or Pocket Park'),
#  ('Access to green space and nature; % homes with access to:; District Park',
#   'District Park'),
#  ('Access to green space and nature; % homes with access to:; Metropolitan Park',
#   'Metropolitan Park'),
#  ('Access to green space and nature; % homes with access to:; Regional Park',
#   'Regional Park'),
#  ('Access to green space and nature; % homes with deficiency in access to nature; 2012',
#   '2012'),
#  ('Access to green space and nature; % area that is greenspace; 2012', '2012'),
#  ('Access to green space and nature; % area that is greenspace; 2014', '2014'),
#  ('Public Transport Accessibility; Average PTAL score; 2010', '2010'),
#  ('Public Transport Accessibility; Average PTAL score; 2011', '2011'),
#  ('Public Transport Accessibility; Average PTAL score; 2012', '2012'),
#  ('Public Transport Accessibility; Average PTAL score; 2014', '2014'),
#  ('Car access; Number of cars or vans in household % - Census 2011; No cars or vans in household %',
#   'No cars or vans in household %'),
#  ('Car access; Number of cars or vans in household % - Census 2011; 1 car or van in household %',
#   '1 car or van in household %'),
#  ('Car access; Number of cars or vans in household % - Census 2011; 2 cars or vans in household %',
#   '2 cars or vans in household %'),
#  ('Car access; Number of cars or vans in household % - Census 2011; 3 cars or vans in household %',
#   '3 cars or vans in household %'),
#  ('Car access; Number of cars or vans in household % - Census 2011; 4 or more cars or vans in household %',
#   '4 or more cars or vans in household %'),
#  ('Car access; Sum of all cars or vans in the area - Census 2011; ',
#   'Unnamed: 870_level_1'),
#  ('Car access; Cars per household - Census 2011; ', 'Unnamed: 871_level_1'),
#  ('Travel to work by bicycle; 2001 Census; All aged 16-74 in work',
#   'All aged 16-74 in work'),
#  ('Travel to work by bicycle; 2001 Census; Travel by bicycle',
#   'Travel by bicycle'),
#  ('Travel to work by bicycle; 2001 Census; % travel by bicycle',
#   '% travel by bicycle'),
#  ('Travel to work by bicycle; 2011 Census; All aged 16-74 in work',
#   'All aged 16-74 in work'),
#  ('Travel to work by bicycle; 2011 Census; Travel by bicycle',
#   'Travel by bicycle'),
#  ('Travel to work by bicycle; 2011 Census; % travel by bicycle',
#   '% travel by bicycle'),
#  ('Indices of Deprivation; Extent; 2007', '2007'),
#  ('Indices of Deprivation; Extent; 2010', '2010'),
#  ('Indices of Deprivation; Rank of extent (within London); 2007', '2007'),
#  ('Indices of Deprivation; Rank of extent (within London); 2010', '2010'),
#  ('Indices of Deprivation; Income Scale; 2007', '2007'),
#  ('Indices of Deprivation; Income Scale; 2010', '2010'),
#  ('Indices of Deprivation; Rank of income scale (within London); 2007',
#   '2007'),
#  ('Indices of Deprivation; Rank of income scale (within London); 2010',
#   '2010'),
#  ('Indices of Deprivation; Employment Scale; 2007', '2007'),
#  ('Indices of Deprivation; Employment Scale; 2010', '2010'),
#  ('Indices of Deprivation; Rank of employment scale (within London); 2007',
#   '2007'),
#  ('Indices of Deprivation; Rank of employment scale (within London); 2010',
#   '2010'),
#  ('Indices of Deprivation; Average Score; 2007', '2007'),
#  ('Indices of Deprivation; Average Score; 2010', '2010'),
#  ('Indices of Deprivation; Rank of average score (within London); 2007',
#   '2007'),
#  ('Indices of Deprivation; Rank of average score (within London); 2010',
#   '2010'),
#  ('Indices of Deprivation; Average Rank; 2007', '2007'),
#  ('Indices of Deprivation; Average Rank; 2010', '2010'),
#  ('Indices of Deprivation; Rank of average rank (within London); 2007',
#   '2007'),
#  ('Indices of Deprivation; Rank of average rank (within London); 2010',
#   '2010'),
#  ('Indices of Deprivation; IDACI; 2007', '2007'),
#  ('Indices of Deprivation; IDACI; 2010', '2010'),
#  ('Indices of Deprivation; Rank of IDACI (within London); 2007', '2007'),
#  ('Indices of Deprivation; Rank of IDACI (within London); 2010', '2010'),
#  ('Indices of Deprivation; IDAOPI; 2007', '2007'),
#  ('Indices of Deprivation; IDAOPI; 2010', '2010'),
#  ('Indices of Deprivation; Rank of IDAOPI (within London); 2007', '2007'),
#  ('Indices of Deprivation; Rank of IDAOPI (within London); 2010', '2010'),
#  ('Indices of Deprivation; Number of SOAs in ward; 2007', '2007'),
#  ('Indices of Deprivation; Number of SOAs in ward; 2010', '2010'),
#  ('Indices of Deprivation; % of LSOAs in worst 5% nationally; 2007', '2007'),
#  ('Indices of Deprivation; % of LSOAs in worst 5% nationally; 2010', '2010'),
#  ('Indices of Deprivation; % of LSOAs in worst 10% nationally; 2007', '2007'),
#  ('Indices of Deprivation; % of LSOAs in worst 10% nationally; 2010', '2010'),
#  ('Indices of Deprivation; % of LSOAs in worst 20% nationally; 2007', '2007'),
#  ('Indices of Deprivation; % of LSOAs in worst 20% nationally; 2010', '2010'),
#  ('Indices of Deprivation; % of LSOAs in worst 50% nationally; 2007', '2007'),
#  ('Indices of Deprivation; % of LSOAs in worst 50% nationally; 2010', '2010'),
#  ('Workplace employment; Total employment; 2009', '2009'),
#  ('Workplace employment; Total employment; 2010', '2010'),
#  ('Workplace employment; Total employment; 2011', '2011'),
#  ('Workplace employment; Total employment; 2012', '2012'),
#  ('Workplace employment; Total employment; 2013', '2013'),
#  ('Workplace employment; Total employees; 2009', '2009'),
#  ('Workplace employment; Total employees; 2010', '2010'),
#  ('Workplace employment; Total employees; 2011', '2011'),
#  ('Workplace employment; Total employees; 2012', '2012'),
#  ('Workplace employment; Total employees; 2013', '2013'),
#  ('Workplace employment; Number of Full-time employees; 2009', '2009'),
#  ('Workplace employment; Number of Full-time employees; 2010', '2010'),
#  ('Workplace employment; Number of Full-time employees; 2011', '2011'),
#  ('Workplace employment; Number of Full-time employees; 2012', '2012'),
#  ('Workplace employment; Number of Full-time employees; 2013', '2013'),
#  ('Workplace employment; Number of Part-time employees; 2009', '2009'),
#  ('Workplace employment; Number of Part-time employees; 2010', '2010'),
#  ('Workplace employment; Number of Part-time employees; 2011', '2011'),
#  ('Workplace employment; Number of Part-time employees; 2012', '2012'),
#  ('Workplace employment; Number of Part-time employees; 2013', '2013'),
#  ('Nat Insurance No. registrations to adult overseas nationals; NINo Registrations; 2007/2008',
#   '2007/2008'),
#  ('Nat Insurance No. registrations to adult overseas nationals; NINo Registrations; 2008/2009',
#   '2008/2009'),
#  ('Nat Insurance No. registrations to adult overseas nationals; NINo Registrations; 2009/2010',
#   '2009/2010'),
#  ('Nat Insurance No. registrations to adult overseas nationals; NINo Registrations; 2010/2011',
#   '2010/2011'),
#  ('Nat Insurance No. registrations to adult overseas nationals; NINo Registrations; 2011/2012',
#   '2011/2012'),
#  ('Election turnout; Turnout Borough election; 2006', '2006'),
#  ('Election turnout; Turnout Borough election; 2010', '2010'),
#  ('Election turnout; Turnout Borough election; 2014', '2014'),
#  ('Election turnout; Turnout Mayoral election; 2008', '2008'),
#  ('Election turnout; Turnout Mayoral election; 2012', '2012')]

# %%
ward_statistics_confounders_2011 = ward_statistics[[('Unnamed: 1_level_0', 'New Code'), 
('Population and Age; Aged 0-15; 2011', '2011'), 
('Population and Age; Aged 16-64; 2011', '2011'), 
 ('Population and Age; Aged 65+; 2011', '2011'),
('Workplace employment; Number of Full-time employees; 2011', '2011'), 
('Workplace employment; Number of Part-time employees; 2011', '2011'),
('Access to green space and nature; % area that is greenspace; 2012', '2012'),
('Access to green space and nature; % homes with deficiency in access to nature; 2012','2012'),
('Benefits claimants; DWP Working-age client group (rates); 2011', '2011'),
('Benefits claimants; Employment and support allowance claimants; 2011','2011'),  
('Benefits claimants; Housing Benefit rates; 2011', '2011'),
('Benefits claimants; Income Support Claimants; 2011', '2011'),
('Benefits claimants; Incapacity Benefit Claimants; 2011', '2011'),
('Jobseekers Allowance; JSA Claimant Rate; 2011', '2011')]]

# %%
ward_statistics_confounders_2012 = ward_statistics[[('Unnamed: 1_level_0', 'New Code'), 
('Population and Age; Aged 0-15; 2012', '2012'), 
('Population and Age; Aged 16-64; 2012', '2012'), 
 ('Population and Age; Aged 65+; 2012', '2012'),
('Workplace employment; Number of Full-time employees; 2012', '2012'), 
('Workplace employment; Number of Part-time employees; 2012', '2012'),
('Access to green space and nature; % area that is greenspace; 2012', '2012'),
('Access to green space and nature; % homes with deficiency in access to nature; 2012','2012'),
('Benefits claimants; DWP Working-age client group (rates); 2012', '2012'),
('Benefits claimants; Employment and support allowance claimants; 2012','2012'),  
('Benefits claimants; Housing Benefit rates; 2012', '2012'),
('Benefits claimants; Income Support Claimants; 2012', '2012'),
('Benefits claimants; Incapacity Benefit Claimants; 2012', '2012'),
('Jobseekers Allowance; JSA Claimant Rate; 2012', '2012')]]

# %%
ward_statistics_confounders_2013 = ward_statistics[[('Unnamed: 1_level_0', 'New Code'), 
('Population and Age; Aged 0-15; 2013', '2013'), 
('Population and Age; Aged 16-64; 2013', '2013'), 
 ('Population and Age; Aged 65+; 2013', '2013'),
('Workplace employment; Number of Full-time employees; 2013', '2013'), 
('Workplace employment; Number of Part-time employees; 2013', '2013'),
('Access to green space and nature; % area that is greenspace; 2012', '2012'),
('Access to green space and nature; % homes with deficiency in access to nature; 2012','2012'),
('Benefits claimants; DWP Working-age client group (rates); 2013', '2013'),
('Benefits claimants; Employment and support allowance claimants; 2013','2013'),  
('Benefits claimants; Housing Benefit rates; 2013', '2013'),
('Benefits claimants; Income Support Claimants; 2013', '2013'),
('Benefits claimants; Incapacity Benefit Claimants; 2013', '2013'),
('Jobseekers Allowance; JSA Claimant Rate; 2013', '2013')]]

# %%
ward_statistics_confounders_2011.set_index(('Unnamed: 1_level_0', 'New Code'), inplace=True)
ward_statistics_confounders_2012.set_index(('Unnamed: 1_level_0', 'New Code'), inplace=True)
ward_statistics_confounders_2013.set_index(('Unnamed: 1_level_0', 'New Code'), inplace=True)

# %%
london_prescriptions_2011_ward_confounders = london_prescriptions_2011_ward_edited.merge(ward_statistics_confounders_2011, how='left', left_on='osward', right_index=True)
london_prescriptions_2012_ward_confounders = london_prescriptions_2012_ward_edited.merge(ward_statistics_confounders_2012, how='left', left_on='osward', right_index=True)
london_prescriptions_2013_ward_confounders = london_prescriptions_2013_ward_edited.merge(ward_statistics_confounders_2013, how='left', left_on='osward', right_index=True)
# Out:
# C:\Users\muize\AppData\Local\Temp\ipykernel_15892\1602393965.py:1: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left, 2 on the right)
#   london_prescriptions_2011_ward_confounders = london_prescriptions_2011_ward_edited.merge(ward_statistics_confounders_2011, how='left', left_on='osward', right_index=True)
# C:\Users\muize\AppData\Local\Temp\ipykernel_15892\1602393965.py:2: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left, 2 on the right)
#   london_prescriptions_2012_ward_confounders = london_prescriptions_2012_ward_edited.merge(ward_statistics_confounders_2012, how='left', left_on='osward', right_index=True)
# C:\Users\muize\AppData\Local\Temp\ipykernel_15892\1602393965.py:3: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left, 2 on the right)
#   london_prescriptions_2013_ward_confounders = london_prescriptions_2013_ward_edited.merge(ward_statistics_confounders_2013, how='left', left_on='osward', right_index=True)

# %% [markdown]
# # Import cultural facilities

# %%
import seaborn as sns
import pandas as pd
import libpysal as ps
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt

# %%
arts_centers = pd.read_csv('data/Arts_centres.csv')
print(arts_centers)
arts_count = arts_centers['ward_2018_code'].value_counts().reset_index()
arts_count.columns = ['ward', 'arts_count']

cinemas = pd.read_csv('data/Cinemas.csv')
cinemas_count = cinemas['ward_2018_code'].value_counts().reset_index()
cinemas_count.columns = ['ward', 'cinema_count']

galleries = pd.read_csv('data/Commercial_galleries.csv')
gallery_count = galleries['ward_2018_code'].value_counts().reset_index()
gallery_count.columns = ['ward', 'gallery_count']

comm_centre = pd.read_csv('data/Community_centres.csv')
comm_centre_count = comm_centre['ward_2018_code'].value_counts().reset_index()
comm_centre_count.columns = ['ward', 'comm_center_count']

dance = pd.read_csv('data/Dance_performance_venues.csv')
dance_count = dance['ward_2018_code'].value_counts().reset_index()
dance_count.columns = ['ward', 'dance_count']

lgbt = pd.read_csv('data/LGBT_night_time_venues.csv')
lgbt_count = lgbt['ward_2018_code'].value_counts().reset_index()
lgbt_count.columns = ['ward', 'lgbt_count']

libraries = pd.read_csv('data/Libraries.csv')
library_count = libraries['ward_2018_code'].value_counts().reset_index()
library_count.columns = ['ward', 'library_count']

museums = pd.read_csv('data/Museums_and_public_galleries.csv')
museum_count = museums['ward_2018_code'].value_counts().reset_index()
museum_count.columns = ['ward', 'museum_count']

music = pd.read_csv('data/Music_venues_all.csv')
music_count = music['ward_2018_code'].value_counts().reset_index()
music_count.columns = ['ward', 'music_count']

outdoor = pd.read_csv('data/Outdoor_spaces_for_cultural_use.csv')
outdoor_count = outdoor['ward_2018_code'].value_counts().reset_index()
outdoor_count.columns = ['ward', 'outdoor_count']

pubs = pd.read_csv('data/Pubs.csv')
pub_count = pubs['ward_2018_code'].value_counts().reset_index()
pub_count.columns = ['ward', 'pub_count']

skate = pd.read_csv('data/Skate_Parks.csv')
skate_count = skate['ward_2018_code'].value_counts().reset_index()
skate_count.columns = ['ward', 'skate_count']

theatres = pd.read_csv('data/Theatres.csv')
theatre_count = theatres['ward_2018_code'].value_counts().reset_index()
theatre_count.columns = ['ward', 'theatre_count']
# Out:
#                               name                           borough_name  \
# 0                      Arts Depot                                  Barnet
# 1           Battersea Arts Centre                              Wandsworth
# 2        Bernie Grant Arts Centre                                Haringey
# 3                    Chats Palace                                 Hackney
# 4                        Dugdale                                  Enfield
# 5              Harrow Arts Centre                                  Harrow
# 6                              ICA                    City of Westminster
# 7           Irish Cultural Centre                  Hammersmith and Fulham
# 8                   Jacksons Lane                                Haringey
# 9                              JW3                                 Camden
# 10                 OSO Arts Centre                   Richmond upon Thames
# 11         Redbridge Drama Centre                               Redbridge
# 12                       Rich Mix                           Tower Hamlets
# 13              Riverside Studios                  Hammersmith and Fulham
# 14               Southbank Centre                                 Lambeth
# 15                  The Tabernacle                 Kensington and Chelsea
# 16                     The Albany                                Lewisham
# 17      The Arts Centre Houndslow                                Hounslow
# 18                   The Barbican   City and County of the City of London
# 19       The Landmark Arts Centre                    Richmond upon Thames
# 20  The Library at Willesdon Green                                  Brent
# 21           Watermans Arts Centre                               Hounslow
# 22                   Poplar Union                           Tower Hamlets
# 23        Streatham Space Project                                 Lambeth
# 24                Fairfield Halls                                 Croydon
# 25   Stratford Circus Arts Centre                                  Newham
#
#                                               website borough_code  \
# 0                        https://www.artsdepot.co.uk/    E09000003
# 1                             https://www.bac.org.uk/    E09000032
# 2                https://www.berniegrantcentre.co.uk/    E09000014
# 3                            https://chatspalace.com/    E09000012
# 4                    https://www.dugdalecentre.co.uk/    E09000010
# 5                             https://harrowarts.com/    E09000015
# 6                          http://www.osoarts.org.uk/    E09000033
# 7                  https://irishculturalcentre.co.uk/    E09000013
# 8                    https://www.jacksonslane.org.uk/    E09000014
# 9                             https://www.jw3.org.uk/    E09000007
# 10                         http://www.osoarts.org.uk/    E09000027
# 11  https://redbridgedramacentre.co.uk/RedbridgeDr...    E09000026
# 12                        https://www.richmix.org.uk/    E09000030
# 13                https://www.riversidestudios.co.uk/    E09000013
# 14                 https://www.southbankcentre.co.uk/    E09000022
# 15                     https://www.tabernaclew11.com/    E09000020
# 16                      https://www.thealbany.org.uk/    E09000023
# 17               http://www.hounslowartscentre.co.uk/    E09000018
# 18                       https://www.barbican.org.uk/    E09000001
# 19                 http://www.landmarkartscentre.org/    E09000027
# 20  https://www.brent.gov.uk/your-council/the-libr...    E09000005
# 21                      https://www.watermans.org.uk/    E09000018
# 22                          https://poplarunion.com/     E09000030
# 23                                                NaN    E09000022
# 24                           https://fairfield.co.uk/    E09000008
# 25                      https://stratford-circus.com/    E09000025
#
#                   address1             address2     address3  \
# 0              5 Nether St       North Finchley          NaN
# 1            Lavender Hill                  NaN          NaN
# 2   Town Hall Approach Rd       Tottenham Green          NaN
# 3    42-44 Brooksby's Walk                  NaN          NaN
# 4           39 London Road              Enfield          NaN
# 5        171 Uxbridge Road            Hatch End          NaN
# 6                 The Mall          St. James's          NaN
# 7             5 Black's Rd          Hammersmith          NaN
# 8          269A Archway Rd             Highgate          NaN
# 9      341-351 Finchley Rd                  NaN          NaN
# 10           49 Station Rd                  NaN          NaN
# 11            Churchfields      South Woodford           NaN
# 12  35-47 Bethnal Green Rd                  NaN          NaN
# 13             19 Crisp Rd          Hammersmith          NaN
# 14          Belvedere Road                  NaN          NaN
# 15         35 Powis Square  off Portobello Road          NaN
# 16             Douglas Way                  NaN          NaN
# 17             First Floor        Treaty Centre  High Street
# 18                 Silk St                  NaN          NaN
# 19   Landmark Arts Centre           Ferry Road    Teddington
# 20            95 High Road           Willesden           NaN
# 21              40 High St           Brentford           NaN
# 22             2 Cotall St               Poplar          NaN
# 23           Sternhold Ave                  NaN          NaN
# 24                 Park Ln                  NaN          NaN
# 25          Theatre Square                  NaN          NaN
#
#     os_addressbase_uprn              ward_2018_name ward_2018_code  longitude  \
# 0             200196017               West Finchley      E05000061  -0.176700
# 1             121015942                 Shaftesbury      E05000623  -0.160814
# 2           10003985252             Tottenham Green      E05000280  -0.073076
# 3          100023020798                 King's Park      E05009379  -0.042683
# 4             207007119                      Grange      E05000200  -0.081118
# 5          200000319916                   Hatch End      E05000291  -0.363803
# 6           10033601867                 St. James's      E05000644  -0.130148
# 7              34156699        Hammersmith Broadway      E05000256  -0.225585
# 8          100023196841                    Highgate      E05000272  -0.145404
# 9               5063874              West Hampstead      E05000145  -0.184819
# 10         200002811148  Mortlake and Barnes Common      E05000525  -0.246626
# 11         100022987836                Churchfields      E05011238   0.022660
# 12              6150258                     Weavers      E05009335  -0.073275
# 13             34157767        Hammersmith Broadway      E05000256  -0.228255
# 14         200000480101                    Bishop's      E05000416  -0.116800
# 15            217070132                    Colville      E05009392  -0.201881
# 16         100023569348                   New Cross      E05000449  -0.027409
# 17          10091692850            Hounslow Central      E05000358  -0.363025
# 18         200000072615                 Cripplegate      E05009302  -0.094103
# 19          10024344794                  Teddington      E05000530  -0.324627
# 20            202149110             Willesden Green      E05000105  -0.228922
# 21         100023407377                   Brentford      E05000347  -0.298042
# 22              6194894                    Lansbury      E05009325  -0.022983
# 23          10093376788              Streatham Hill      E05000430  -0.127655
# 24         100022917675                   Fairfield      E05011468  -0.095778
# 25          10008996899      Stratford and New Town      E05000492   0.001744
#
#      latitude        easting       northing     runtime
# 0   51.612816  526119.802408  192122.615357  11/27/2022
# 1   51.465163  527632.180881  175734.049826  11/27/2022
# 2   51.587475  533366.644110  189489.184290  11/27/2022
# 3   51.550264  535582.402990  185408.019413  11/27/2022
# 4   51.650318  532626.255040  196461.371427  11/27/2022
# 5   51.608489  513179.302693  191334.817592  11/27/2022
# 6   51.506710  529643.663226  180407.136333  11/27/2022
# 7   51.492313  523061.035613  178641.570480  11/27/2022
# 8   51.576681  528387.977569  188159.603513  11/27/2022
# 9   51.550940  525728.603837  185229.182502  11/27/2022
# 10  51.472301  521654.046727  176381.361879  11/27/2022
# 11  51.598453  539963.126887  190888.736179  11/27/2022
# 12  51.524359  533537.848753  182471.723561  11/27/2022
# 13  51.488909  522884.842927  178258.589429  11/27/2022
# 14  51.505768  530572.457992  180326.162499  11/27/2022
# 15  51.516968  524638.782098  181422.889007  11/27/2022
# 16  51.477877  536857.999972  177388.663954  11/27/2022
# 17  51.468134  513582.343910  175730.816397  11/27/2022
# 18  51.519961  532106.142119  181944.876332  11/27/2022
# 19  51.428087  516350.585418  171338.755264  11/27/2022
# 20  51.546650  522683.287380  184677.260153  11/27/2022
# 21  51.485768  518049.178450  177794.407941  11/27/2022
# 22  51.515600  537052.076038  181590.911568  11/27/2022
# 23  51.438785  530009.820051  172859.723636  11/27/2022
# 24  51.372524  532416.148263  165550.228723  11/27/2022
# 25  51.542717  538684.710456  184652.345457  11/27/2022

# %%
london = gpd.read_file('shapefiles/London-wards-2018_ESRI/London_Ward.shp')
london.set_index('GSS_CODE')
# print(london[london['GSS_CODE'] == 'E05000029'])
london = london.merge(arts_count, left_on='GSS_CODE', right_on='ward', how='left')
london = london.merge(cinemas_count, left_on='GSS_CODE', right_on='ward', how='left')
london = london.merge(gallery_count, left_on='GSS_CODE', right_on='ward', how='left')
london = london.merge(comm_centre_count, left_on='GSS_CODE', right_on='ward', how='left')
london = london.merge(dance_count, left_on='GSS_CODE', right_on='ward', how='left')
london = london.merge(lgbt_count, left_on='GSS_CODE', right_on='ward', how='left')
london = london.merge(library_count, left_on='GSS_CODE', right_on='ward', how='left')
london = london.merge(museum_count, left_on='GSS_CODE', right_on='ward', how='left')
london = london.merge(music_count, left_on='GSS_CODE', right_on='ward', how='left')
london = london.merge(outdoor_count, left_on='GSS_CODE', right_on='ward', how='left')
london = london.merge(pub_count, left_on='GSS_CODE', right_on='ward', how='left')
london = london.merge(skate_count, left_on='GSS_CODE', right_on='ward', how='left')
london = london.merge(theatre_count, left_on='GSS_CODE', right_on='ward', how='left')

london = london[['GSS_CODE', 'arts_count', 'cinema_count', 'gallery_count', 'comm_center_count', 
    'dance_count', 'lgbt_count', 'library_count', 'museum_count', 
    'music_count', 'outdoor_count', 'pub_count', 'skate_count', 'theatre_count']]
london = london.fillna(0)
london['total_count'] = london['arts_count'] + london['cinema_count'] + london['gallery_count'] + london['comm_center_count'] + london['dance_count'] + london['lgbt_count'] + london['library_count'] + london['museum_count'] + london['music_count'] + london['outdoor_count'] + london['pub_count'] + london['skate_count'] + london['theatre_count']
cultural_facilities = london
# Out:
# C:\Users\muize\AppData\Roaming\Python\Python310\site-packages\geopandas\geodataframe.py:1499: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ward_x'} in the result is deprecated and will raise a MergeError in a future version.
#   result = DataFrame.merge(self, *args, **kwargs)
# C:\Users\muize\AppData\Roaming\Python\Python310\site-packages\geopandas\geodataframe.py:1499: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ward_x'} in the result is deprecated and will raise a MergeError in a future version.
#   result = DataFrame.merge(self, *args, **kwargs)
# C:\Users\muize\AppData\Roaming\Python\Python310\site-packages\geopandas\geodataframe.py:1499: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ward_x'} in the result is deprecated and will raise a MergeError in a future version.
#   result = DataFrame.merge(self, *args, **kwargs)
# C:\Users\muize\AppData\Roaming\Python\Python310\site-packages\geopandas\geodataframe.py:1499: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ward_x'} in the result is deprecated and will raise a MergeError in a future version.
#   result = DataFrame.merge(self, *args, **kwargs)
# C:\Users\muize\AppData\Roaming\Python\Python310\site-packages\geopandas\geodataframe.py:1499: FutureWarning: Passing 'suffixes' which cause duplicate columns {'ward_x'} in the result is deprecated and will raise a MergeError in a future version.
#   result = DataFrame.merge(self, *args, **kwargs)

# %%
london_prescriptions_2011_ward_confounders_facilities = london_prescriptions_2011_ward_confounders.merge(cultural_facilities, how='left', left_on='osward', right_on='GSS_CODE')
london_prescriptions_2012_ward_confounders_facilities = london_prescriptions_2012_ward_confounders.merge(cultural_facilities, how='left', left_on='osward', right_on='GSS_CODE')
london_prescriptions_2013_ward_confounders_facilities = london_prescriptions_2013_ward_confounders.merge(cultural_facilities, how='left', left_on='osward', right_on='GSS_CODE')

# %%
grouped_mean = london_prescriptions_2011_ward_confounders_facilities.groupby(["osward"]).mean()
grouped_mean_no_nan = grouped_mean.fillna(0)
full_dataset_confounders = grouped_mean_no_nan.drop(['Unnamed: 0', 'ITEMS  ', 'NIC        ', 'ACT COST   ', 'PERIOD'], axis=1)
full_dataset_confounders.to_csv('processed_data/full_dataset_confounders_2011.csv')
# Out:
# Index([                                                                                   'Unnamed: 0',
#                                                                                              'ITEMS  ',
#                                                                                          'NIC        ',
#                                                                                          'ACT COST   ',
#                                                                                             'QUANTITY',
#                                                                                               'PERIOD',
#                                                        ('Population and Age; Aged 0-15; 2011', '2011'),
#                                                       ('Population and Age; Aged 16-64; 2011', '2011'),
#                                                         ('Population and Age; Aged 65+; 2011', '2011'),
#                                  ('Workplace employment; Number of Full-time employees; 2011', '2011'),
#                                  ('Workplace employment; Number of Part-time employees; 2011', '2011'),
#                          ('Access to green space and nature; % area that is greenspace; 2012', '2012'),
#        ('Access to green space and nature; % homes with deficiency in access to nature; 2012', '2012'),
#                             ('Benefits claimants; DWP Working-age client group (rates); 2011', '2011'),
#                       ('Benefits claimants; Employment and support allowance claimants; 2011', '2011'),
#                                            ('Benefits claimants; Housing Benefit rates; 2011', '2011'),
#                                         ('Benefits claimants; Income Support Claimants; 2011', '2011'),
#                                     ('Benefits claimants; Incapacity Benefit Claimants; 2011', '2011'),
#                                              ('Jobseekers Allowance; JSA Claimant Rate; 2011', '2011'),
#                                                                                           'arts_count',
#                                                                                         'cinema_count',
#                                                                                        'gallery_count',
#                                                                                    'comm_center_count',
#                                                                                          'dance_count',
#                                                                                           'lgbt_count',
#                                                                                        'library_count',
#                                                                                         'museum_count',
#                                                                                          'music_count',
#                                                                                        'outdoor_count',
#                                                                                            'pub_count',
#                                                                                          'skate_count',
#                                                                                        'theatre_count',
#                                                                                          'total_count'],
#       dtype='object')
# C:\Users\muize\AppData\Local\Temp\ipykernel_15892\2973736321.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_mean = london_prescriptions_2011_ward_confounders_facilities.groupby(["osward"]).mean()

# %%
grouped_mean = london_prescriptions_2012_ward_confounders_facilities.groupby(["osward"]).mean()
grouped_mean_no_nan = grouped_mean.fillna(0)
full_dataset_confounders = grouped_mean_no_nan.drop(['Unnamed: 0', 'ITEMS  ', 'NIC        ', 'ACT COST   ', 'PERIOD'], axis=1)
full_dataset_confounders.to_csv('processed_data/full_dataset_confounders_2012.csv')
# Out:
# C:\Users\muize\AppData\Local\Temp\ipykernel_15892\1164724889.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_mean = london_prescriptions_2012_ward_confounders_facilities.groupby(["osward"]).mean()

# %%
grouped_mean = london_prescriptions_2013_ward_confounders_facilities.groupby(["osward"]).mean()
grouped_mean_no_nan = grouped_mean.fillna(0)
full_dataset_confounders = grouped_mean_no_nan.drop(['Unnamed: 0', 'ITEMS  ', 'NIC        ', 'ACT COST   ', 'PERIOD'], axis=1)
full_dataset_confounders.to_csv('processed_data/full_dataset_confounders_2013.csv')
# Out:
# C:\Users\muize\AppData\Local\Temp\ipykernel_15892\2798427759.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_mean = london_prescriptions_2013_ward_confounders_facilities.groupby(["osward"]).mean()
